# %%
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import numpy as np
import pandas as pd
import os 
from torch.utils.data import DataLoader, TensorDataset
import torch

# %%
#%matplotlib notebook

# %%
seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
num_epochs = 10000

# %%
# Load the conditions into a Pandas DataFrame
excel_path = './conditions.xlsx'
conditions_df = pd.read_excel(excel_path)

# Display the DataFrame to verify the contents
conditions_df
# Out:
#   Sample Name  Power (W)  Speed (mm/s)
# 0           a         71            21
# 1           b         85            30
# 2           c         55            21
# 3           d         66            30
# 4           e         85            50
# 5           f         55            30
# 6           g         70            50

# %%
## Set up the main parameters are all in mm
spot_radius = 0.142 / 2
eta = 0.44
O_PD = 0.02

T_amb = 27.0

rho = 8000 *1e-9 #kg/(mm)^3
Cp = 500.0 #J/(kgK)
kappa = 20 * 1e-3 #W/(mmK)

T_max = 5500 #K
T_min = T_amb

T_melt = 1417

mu = 7 #mPa s
dgamma_dt = 2e-4 #N/(m * K)

# %%
# Set up the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# Function to get CSV files in a folder
def get_csv_files_in_folder(folder_path):
    csv_file_paths = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):
            full_file_path = os.path.join(folder_path, filename)
            csv_file_paths.append(full_file_path)
    return csv_file_paths

# Function to extract sample name from CSV file name
def extract_sample_name_from_csv(filename):
    # The sample name is the part of the filename before the last underscore or the file extension
    return os.path.splitext(filename)[0].split('_')[-1]

# %%
# Folder_path is where the CSV files are stored
folder_path = './Data/'  
csv_file_paths = get_csv_files_in_folder(folder_path)

csv_file_paths
# Out:
# ['./Data/data_sample_f.csv',
#  './Data/data_sample_g.csv',
#  './Data/data_sample_d.csv',
#  './Data/data_sample_b.csv',
#  './Data/data_sample_e.csv',
#  './Data/data_sample_c.csv',
#  './Data/data_sample_a.csv']

# %%
# Dictionary to store summary statistics for each dataset
summary_statistics = {}

# Loop through each file path and generate summary statistics
for file_path in csv_file_paths:
    df = pd.read_csv(file_path)
    filename = os.path.basename(file_path)
    sample_name = extract_sample_name_from_csv(filename)
    
    if sample_name in conditions_df['Sample Name'].values:
        summary_statistics[sample_name] = df.describe()
    else:
        print(f"Warning: Sample name {sample_name} from {filename} not found in Excel data.")

# Display the summary statistics for verification
for sample, stats in summary_statistics.items():
    print(f"Summary statistics for sample {sample}:\n{stats}\n")
# Out:
# Summary statistics for sample f:
#             x(um)       y(um)    Vx(mm/s)    Vy(mm/s)  Circular variance  \
# count  406.000000  406.000000  406.000000  406.000000         406.000000
# mean    85.377500  -78.810000   -3.478527   10.807335           0.095253
# std    110.030884   53.014206   64.638946   69.059161           0.215684
# min    -98.512500 -164.187500 -345.191740 -472.860000           0.000000
# 25%     -6.567500 -124.782500    0.000000    0.000000           0.000000
# 50%     85.377500  -78.810000    0.000000    0.000000           0.000000
# 75%    177.322500  -32.837500    0.000000    0.000000           0.000000
# max    269.267500    6.567500  337.828260  275.835000           0.962551
#
#        particle numbers
# count        406.000000
# mean           0.876847
# std            1.917974
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max           10.000000
#
# Summary statistics for sample g:
#             x(um)       y(um)    Vx(mm/s)    Vy(mm/s)  Circular variance  \
# count  405.000000  405.000000  405.000000  405.000000         405.000000
# mean    72.242500  -45.972500   -4.029064    4.396171           0.107504
# std    102.433491   56.819877   56.907633   63.788638           0.238721
# min    -98.512500 -137.917500 -391.747434 -433.455000           0.000000
# 25%    -19.702500  -98.512500    0.000000    0.000000           0.000000
# 50%     72.242500  -45.972500    0.000000    0.000000           0.000000
# 75%    164.187500    6.567500    0.000000    0.000000           0.000000
# max    242.997500   45.972500  383.217565  394.050000           0.973342
#
#        particle numbers
# count        405.000000
# mean           0.723457
# std            1.748427
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max           15.000000
#
# Summary statistics for sample d:
#             x(um)       y(um)    Vx(mm/s)    Vy(mm/s)  Circular variance  \
# count  558.000000  558.000000  558.000000  558.000000         558.000000
# mean    98.512500  -91.945000   -2.020757   26.537934           0.129238
# std    117.588425   68.207199   69.186142   65.338867           0.239377
# min    -98.512500 -203.592500 -305.877372 -354.645000           0.000000
# 25%     -6.567500 -151.052500    0.000000    0.000000           0.000000
# 50%     98.512500  -91.945000    0.000000    0.000000           0.000000
# 75%    203.592500  -32.837500    0.000000   35.464500           0.156415
# max    295.537500   19.702500  262.680485  288.970000           0.981907
#
#        particle numbers
# count        558.000000
# mean           2.396057
# std            4.227267
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            4.000000
# max           23.000000
#
# Summary statistics for sample b:
#             x(um)       y(um)    Vx(mm/s)    Vy(mm/s)  Circular variance  \
# count  651.000000  651.000000  651.000000  651.000000         651.000000
# mean    98.512500 -111.647500   -5.703663   28.177572           0.131012
# std    117.573348   79.597533   74.133421   63.373442           0.230636
# min    -98.512500 -242.997500 -266.429027 -341.510000           0.000000
# 25%     -6.567500 -177.322500    0.000000    0.000000           0.000000
# 50%     98.512500 -111.647500    0.000000    0.000000           0.000000
# 75%    203.592500  -45.972500    0.000000   52.540000           0.198239
# max    295.537500   19.702500  337.780974  252.192000           0.952635
#
#        particle numbers
# count        651.000000
# mean           2.393241
# std            3.784041
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            5.000000
# max           19.000000
#
# Summary statistics for sample e:
#             x(um)       y(um)    Vx(mm/s)    Vy(mm/s)  Circular variance  \
# count  496.000000  496.000000  496.000000  496.000000         496.000000
# mean    98.512500  -78.810000   -6.006760   23.080160           0.143265
# std    117.601621   60.610488   81.547074   68.775552           0.262916
# min    -98.512500 -177.322500 -404.409575 -341.510000           0.000000
# 25%     -6.567500 -128.066250    0.000000    0.000000           0.000000
# 50%     98.512500  -78.810000    0.000000    0.000000           0.000000
# 75%    203.592500  -29.553750    0.000000    0.000000           0.174965
# max    295.537500   19.702500  403.392925  315.240000           1.000000
#
#        particle numbers
# count        496.000000
# mean           2.356855
# std            4.499571
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            4.000000
# max           28.000000
#
# Summary statistics for sample c:
#             x(um)       y(um)    Vx(mm/s)    Vy(mm/s)  Circular variance  \
# count  496.000000  496.000000  496.000000  496.000000         496.000000
# mean    98.512500  -65.675000   -0.139207   34.804049           0.174548
# std    117.601621   60.610488   76.529003   67.414049           0.276786
# min    -98.512500 -164.187500 -268.588983 -288.970000           0.000000
# 25%     -6.567500 -114.931250    0.000000    0.000000           0.000000
# 50%     98.512500  -65.675000    0.000000    0.000000           0.000000
# 75%    203.592500  -16.418750    0.000000   75.995357           0.346332
# max    295.537500   32.837500  268.069588  394.050000           0.960499
#
#        particle numbers
# count        496.000000
# mean           2.993952
# std            4.758190
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            6.000000
# max           21.000000
#
# Summary statistics for sample a:
#             x(um)       y(um)    Vx(mm/s)    Vy(mm/s)  Circular variance  \
# count  713.000000  713.000000  713.000000  713.000000         713.000000
# mean    98.512500  -98.512500    1.347204   29.124657           0.158467
# std    117.565485   87.188897   69.548116   58.915227           0.258714
# min    -98.512500 -242.997500 -241.647222 -315.240000           0.000000
# 25%     -6.567500 -177.322500    0.000000    0.000000           0.000000
# 50%     98.512500  -98.512500    0.000000    0.000000           0.000000
# 75%    203.592500  -19.702500    0.000000   66.550667           0.261431
# max    295.537500   45.972500  249.226492  262.700000           0.977145
#
#        particle numbers
# count        713.000000
# mean           4.684432
# std            7.838611
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            8.000000
# max           45.000000

# %%
# Dictionary to store the actual data for each dataset
data_frames = {}

# Loop through each file path, read the data, and store both the summary statistics and the data
for file_path in csv_file_paths:
    df = pd.read_csv(file_path)
    filename = os.path.basename(file_path)
    sample_name = extract_sample_name_from_csv(filename)
    
    if sample_name in conditions_df['Sample Name'].values:
        summary_statistics[sample_name] = df.describe()
        data_frames[sample_name] = df  # Storing the actual data
    else:
        print(f"Warning: Sample name {sample_name} from {filename} not found in Excel data.")

# %%
# Define the variable names
variables = list(summary_statistics['a'].columns)

# Loop through each sample and create quiver plots for x and y
for sample, df in data_frames.items():
    plt.figure(figsize=(10, 8))
    
    # Find the minimum absolute distance to y=0
    min_distance_to_zero = np.min(np.abs(df[variables[1]]))

    # Identify all rows where y is closest to 0
    closest_to_zero_rows = df[np.abs(df[variables[1]]) == min_distance_to_zero]

    # Filter to get only the negative y values
    closest_to_zero_rows_negative = closest_to_zero_rows[closest_to_zero_rows[variables[1]] < 0]

    # Quiver plot to show vectors; setting scale to make arrows smaller
    plt.quiver(df[variables[0]], df[variables[1]], df[variables[2]], df[variables[3]], 
               angles='xy', scale_units='xy', scale=20, color='blue', alpha=0.6, label=f'Sample {sample} Vectors')

    # Highlight the negative points closest to y=0 with red dots
    plt.scatter(closest_to_zero_rows_negative[variables[0]], closest_to_zero_rows_negative[variables[1]], 
                color='red', zorder=5, label='Surface')
    
    # Labels and title
    plt.xlabel(variables[0])
    plt.ylabel(variables[1])
    plt.title(f'Quiver Plot of Vectors for Sample {sample}')
    plt.legend()
    
    plt.show()
    break

# %%
# Resolution for the grid
resolution = 13.135  # in um

# Calculate the number of points on either side of z=0
num_points_side = int(200 / resolution)

# Generate z coordinates ranging from -50 um to +50 um with the given resolution
# Make sure to include 0 in the middle
z_coordinates = torch.cat([
    torch.arange(-num_points_side * resolution, -0.1, resolution),  # Left of zero
    torch.tensor([0.0]),                                          # Zero
    torch.arange(resolution, num_points_side * resolution + 0.1, resolution)  # Right of zero
])

# Dictionary to store the 3D coordinates as PyTorch tensors for each sample
sample_coordinates = {}

# Loop through each sample and create 3D coordinates
for sample, df in data_frames.items():
    # Extract x and y coordinates from the DataFrame and convert them to PyTorch tensors
    x_coordinates = torch.tensor(df[variables[0]].values, dtype=torch.float32)
    y_coordinates = torch.tensor(df[variables[1]].values, dtype=torch.float32)
    
    # Create empty tensor to store the 3D coordinates (x, y, z) for each point
    total_points = len(x_coordinates) * len(z_coordinates)
    coords_3D = torch.zeros(total_points, 3)
    
    # Fill the 3D coordinates tensor
    index = 0
    for z in z_coordinates:
        for i in range(len(x_coordinates)):
            coords_3D[index, 0] = x_coordinates[i]
            coords_3D[index, 1] = y_coordinates[i]
            coords_3D[index, 2] = z
            index += 1
    
    # Store the 3D coordinates tensor for the sample
    sample_coordinates[sample] = coords_3D

# After generating 3D coordinates for all samples
# Loop to filter out coordinates with positive y-values
for sample in sample_coordinates.keys():
    coords_3D = sample_coordinates[sample]
    coords_filtered = coords_3D[coords_3D[:, 1] <= 0]
    sample_coordinates[sample] = coords_filtered

# %%
# Initialize variables to store the global maximum and minimum values for x, y, and z
global_x_max = float('-inf')
global_y_max = float('-inf')
global_z_max = float('-inf')
global_x_min = float('inf')
global_y_min = float('inf')
global_z_min = float('inf')

# Loop through each sample to find the global maximum and minimum for x, y, and z
for sample, coords in sample_coordinates.items():
    global_x_max = max(global_x_max, coords[:, 0].max())
    global_y_max = max(global_y_max, coords[:, 1].max())
    global_z_max = max(global_z_max, coords[:, 2].max())
    
    global_x_min = min(global_x_min, coords[:, 0].min())
    global_y_min = min(global_y_min, coords[:, 1].min())
    global_z_min = min(global_z_min, coords[:, 2].min())

# Calculate the global minimum and maximum values for speed and power
global_speed_min = conditions_df['Speed (mm/s)'].min()
global_speed_max = conditions_df['Speed (mm/s)'].max()
global_power_min = conditions_df['Power (W)'].min()
global_power_max = conditions_df['Power (W)'].max()

# Display the calculated global values
print(f"Global Minimum Speed: {global_speed_min} mm/s")
print(f"Global Maximum Speed: {global_speed_max} mm/s")
print(f"Global Minimum Power: {global_power_min} W")
print(f"Global Maximum Power: {global_power_max} W")
print(f"Global Maximum X: {global_x_max} um")
print(f"Global Maximum Y: {global_y_max} um")
print(f"Global Maximum Z: {global_z_max} um")
print(f"Global Minimum X: {global_x_min} um")
print(f"Global Minimum Y: {global_y_min} um")
print(f"Global Minimum Z: {global_z_min} um")
# Out:
# Global Minimum Speed: 21 mm/s
# Global Maximum Speed: 50 mm/s
# Global Minimum Power: 55 W
# Global Maximum Power: 85 W
# Global Maximum X: 295.5375061035156 um
# Global Maximum Y: -6.567500114440918 um
# Global Maximum Z: 197.02499389648438 um
# Global Minimum X: -98.51249694824219 um
# Global Minimum Y: -242.99749755859375 um
# Global Minimum Z: -197.02499389648438 um

# %%
# Dictionary to store the boundary and interior coordinates as PyTorch tensors for each sample
sample_boundary_coordinates = {}
sample_interior_coordinates = {}

# Loop through each sample and separate boundary and interior points
for sample, coords_3D in sample_coordinates.items():
    x_min = coords_3D[:, 0].min()
    x_max = coords_3D[:, 0].max()
    y_min = coords_3D[:, 1].min()
    
    # Define conditions for boundary points
    cond_x_min = (coords_3D[:, 0] == x_min)
    cond_x_max = (coords_3D[:, 0] == x_max)
    cond_y_min = (coords_3D[:, 1] == y_min)
    
    # Extract boundary points
    boundary_points = coords_3D[cond_x_max | cond_y_min] # cond_x_min
    
    # Extract interior points
    interior_points = coords_3D[~(cond_x_max | cond_y_min)] # cond_x_min
    
    # Store them in dictionaries
    sample_boundary_coordinates[sample] = boundary_points
    sample_interior_coordinates[sample] = interior_points

# `sample_boundary_coordinates` contains the boundary points and
# `sample_interior_coordinates` contains the interior points for each sample.

# %%
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.pyplot as plt

# # Loop through each sample and plot the 3D coordinates
# for sample in sample_coordinates.keys():
#     fig = plt.figure(figsize=(10, 8))
#     ax = fig.add_subplot(111, projection='3d')
    
#     # Scatter plot in 3D for interior points in blue
#     interior_coords = sample_interior_coordinates[sample]
#     ax.scatter(interior_coords[:, 0], interior_coords[:, 1], interior_coords[:, 2], c='b', marker='o', alpha=0.2)
    
#     # Scatter plot in 3D for boundary points in red
#     boundary_coords = sample_boundary_coordinates[sample]
#     ax.scatter(boundary_coords[:, 0], boundary_coords[:, 1], boundary_coords[:, 2], c='r', marker='o', alpha=0.5)
    
#     # Labels and title
#     ax.set_xlabel('X (um)')
#     ax.set_ylabel('Y (um)')
#     ax.set_zlabel('Z (um)')
#     ax.set_title(f'3D Scatter Plot for Sample {sample} (Interior in Blue, Boundary in Red)')
    
#     plt.show()
#     break

# %%
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.pyplot as plt

# # Loop through each sample and plot the 3D coordinates with velocity vectors at z=0
# for sample in sample_coordinates.keys():
#     fig = plt.figure(figsize=(10, 8))
#     ax = fig.add_subplot(111, projection='3d')
    
#     # Scatter plot in 3D for interior points in blue
#     interior_coords = sample_interior_coordinates[sample]
#     ax.scatter(interior_coords[:, 0], interior_coords[:, 1], interior_coords[:, 2], c='b', marker='o', alpha=0.1, label='Interior Coordinates')
    
#     # Scatter plot in 3D for boundary points in red
#     boundary_coords = sample_boundary_coordinates[sample]
#     ax.scatter(boundary_coords[:, 0], boundary_coords[:, 1], boundary_coords[:, 2], c='r', marker='o', alpha=0.5, label='Boundary Coordinates')
    
#     # Extract data for the sample
#     df_sample = data_frames[sample]
#     x_values = df_sample[variables[0]].values
#     y_values = df_sample[variables[1]].values
#     vx_values = df_sample[variables[2]].values
#     vy_values = df_sample[variables[3]].values
    
#     # Quiver plot for fluid velocity vectors at z=0
#     ax.quiver(x_values, y_values, 0, vx_values, vy_values, 0, color='g', length=0.1, arrow_length_ratio=0.2, label='Velocity Vectors at z=0')
    
#     # Labels and title
#     ax.set_xlabel('X (um)')
#     ax.set_ylabel('Y (um)')
#     ax.set_zlabel('Z (um)')
#     ax.set_title(f'3D Scatter Plot with Velocity Vectors for Sample {sample}')
#     ax.legend()
    
#     plt.show()
#     break

# %%
def heat_source(coords: torch.Tensor, power: torch.Tensor, spot_radius: torch.Tensor, eta: torch.Tensor) -> torch.Tensor:
    """
    Computes the heat source based on the input values 
    of x, y, z, power, spot_radius, eta_bulk, eta_powder and O_PD.
    
    Parameters:
        coordinates (torch.Tensor): tensor of coordinate values
        power (torch.Tensor): power value
        eta (torch.Tensor): absorption 
        spot_radius (torch.Tensor): spot radius value (1/e)
    
    Returns:
        Q (torch.Tensor): tensor of heat flux
    """
    x, y, z = coords[:, 0], coords[:, 1], coords[:, 2]
    power = power.view(-1)
    
    # Compute the Gaussian heat source
    Q = 2 * (eta * power) / (torch.pi * spot_radius ** 2 * O_PD * torch.sqrt(torch.tensor(torch.pi))) * torch.exp(
        -((x ** 2) / (spot_radius ** 2) + (z ** 2) / (spot_radius ** 2) + (y ** 2) / (O_PD ** 2)))
    
    # Mask to zero out Q values where y is non-negative
    mask = (y >= 0)
    Q[mask] = 0
    
    return Q

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Parameters for heat source (convert them to PyTorch tensors)
power = torch.tensor(global_power_max)

# Loop through each sample and plot the 3D coordinates with heat source
for sample in sample_coordinates.keys():
    # Filter the coordinates to only include the plane with y coordinate closest to 0 and negative
    df_sample = data_frames[sample]
    min_distance_to_zero = np.min(np.abs(df_sample[variables[1]].values))
    closest_to_zero_negative_y = df_sample[np.abs(df_sample[variables[1]].values) == min_distance_to_zero]
    closest_to_zero_negative_y = closest_to_zero_negative_y[closest_to_zero_negative_y[variables[1]] < 0]
    
    filtered_coords = sample_coordinates[sample][(sample_coordinates[sample][:, 1] == closest_to_zero_negative_y[variables[1]].values[0]).nonzero().squeeze(), :]
    boundary_coords = sample_boundary_coordinates[sample][(sample_boundary_coordinates[sample][:, 1] == closest_to_zero_negative_y[variables[1]].values[0]).nonzero().squeeze(), :]
    interior_coords = sample_interior_coordinates[sample][(sample_interior_coordinates[sample][:, 1] == closest_to_zero_negative_y[variables[1]].values[0]).nonzero().squeeze(), :]
    
    # Compute heat source for the boundary and interior coordinates
    Q_values_boundary = heat_source(boundary_coords / 1000, power, spot_radius, eta)
    Q_values_interior = heat_source(interior_coords / 1000, power, spot_radius, eta)
    
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    # Scatter plot in 3D colored by heat source values for boundary points
    scatter_boundary = ax.scatter(boundary_coords[:, 0], boundary_coords[:, 1], boundary_coords[:, 2], 
                                  c=Q_values_boundary, cmap=cm.jet, marker='x', alpha=0.5, label='Boundary Points')
    
    # Scatter plot in 3D colored by heat source values for interior points
    scatter_interior = ax.scatter(interior_coords[:, 0], interior_coords[:, 1], interior_coords[:, 2], 
                                  c=Q_values_interior, cmap=cm.jet, marker='o', alpha=0.2, label='Interior Points')
 
    
    # Add a color bar to indicate heat source values
    cbar = plt.colorbar(scatter_boundary)
    cbar.set_label('Heat Source (Q)')
    
    # Set axis limits to preserve actual proportions based on the filtered coordinates
    ax.set_xlim([filtered_coords[:, 0].min(), filtered_coords[:, 0].max()])
    ax.set_ylim([filtered_coords[:, 1].min(), filtered_coords[:, 1].max()])
    ax.set_zlim([filtered_coords[:, 2].min(), filtered_coords[:, 2].max()])
    
    # Labels and title
    ax.set_xlabel('X (um)')
    ax.set_ylabel('Y (um)')
    ax.set_zlabel('Z (um)')
    ax.set_title(f'3D Scatter Plot of Melt Pool Surface with Heat Source for Sample {sample}')
    ax.legend()
    
    plt.show()
    break
# Out:
# <ipython-input-19-76472ae05d76>:43: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim([filtered_coords[:, 1].min(), filtered_coords[:, 1].max()])

# %%
import torch
import torch.nn as nn

class TempFieldNN(nn.Module):
    def __init__(self, T_amb):
        super(TempFieldNN, self).__init__()

        # Define wide but shallow layers
        self.layer1 = nn.Linear(5, 5000)
        self.layer2 = nn.Linear(5000, 5000)
        self.layer_out = nn.Linear(5000, 1)

        # Initialize the bias of the output layer to T_amb
        nn.init.constant_(self.layer_out.bias, T_amb)

    def forward(self, x):
        # First layer followed by activation
        x1 = self.layer1(x)
        x1_act = torch.tanh(x1)

        # Second layer followed by activation
        x2 = self.layer2(x1_act)
        x2_act = torch.tanh(x2)

        # Residual connection using multiplication
        x_res = x1_act + x2_act

        # Output layer
        x_out = self.layer_out(x_res)
        
        return x_out



# Fluid Flow Neural Network
class FluidFlowNN(nn.Module):
    def __init__(self):
        super(FluidFlowNN, self).__init__()
        self.layer1 = nn.Linear(5, 2048*4)
        self.layer2 = nn.Linear(2048*4, 512*4)
        self.layer_out = nn.Linear(512*4, 3)
        self.silu = nn.SiLU()
        
    def forward(self, x):
        x = self.layer1(x)
        x = self.silu(x)
        x = self.layer2(x)
        x = self.silu(x)
        x = self.layer_out(x)
        return x

# Instantiate the neural networks
#temp_net = TempFieldNN()
#fluid_net = FluidFlowNN()

# # Print the architectures
# print("Temperature Field Neural Network architecture:")
# print(temp_net)
# print("\nFluid Flow Neural Network architecture:")
# print(fluid_net)

# %% [markdown]
# Next steps:
# - write a function to normalize the network input
# - output can stay unnormalized
# - write function to generate boundary data at random
# - remember to use cross-validation
# - write custom loss

# %%
def normalize_tensor(tensor, min_val, max_val):
    """
    Normalize a tensor to range [-1, 1].

    Parameters:
        tensor (torch.Tensor): The tensor to normalize.
        min_val (float): The minimum value for normalization.
        max_val (float): The maximum value for normalization.

    Returns:
        torch.Tensor: The normalized tensor.
    """
    return ((tensor - min_val) / (max_val - min_val)) * 2 - 1

# %%
def normalize_coordinates(tensor, x_min, x_max, y_min, y_max, z_min, z_max):
    normalized_tensor = tensor.clone()  # Create a new tensor
    normalized_tensor[:, 0] = ((tensor[:, 0] - x_min) / (x_max - x_min)) * 2 - 1  # Normalize x
    normalized_tensor[:, 1] = ((tensor[:, 1] - y_min) / (y_max - y_min)) * 2 - 1  # Normalize y
    normalized_tensor[:, 2] = ((tensor[:, 2] - z_min) / (z_max - z_min)) * 2 - 1  # Normalize z
    return normalized_tensor

# %%
from torch.utils.data import DataLoader, TensorDataset

# Create a list of sample identifiers
sample_identifiers = list(sample_coordinates.keys())
sample_identifiers
# Out:
# ['f', 'g', 'd', 'b', 'e', 'c', 'a']

# %%
from torch.utils.data import DataLoader, Dataset, TensorDataset
import torch

# Custom Dataset to handle sample-specific data
class SampleSpecificDataset(Dataset):
    def __init__(self, sample_data_list):
        self.data_list = sample_data_list
    
    def __len__(self):
        return len(self.data_list)
    
    def __getitem__(self, index):
        return self.data_list[index]

def create_data_loader(exclude_sample, x_max, x_min, y_max, y_min, z_max, z_min, 
                       sample_coordinates, sample_boundary_coordinates, sample_interior_coordinates, 
                       conditions_df, data_frames, verbose=False):
    
    if (verbose):
        print("Starting the create_data_loader function...")
    
    training_data_list = []
    validation_data_list = []
    
    if (verbose):
        print("Initialized empty lists for storing sample-specific data.")
    
    for sample in sample_coordinates.keys():
        
        if (verbose):
            print('----'*8)
            print(f"Processing sample: {sample}")
        
        # Extract and normalize conditions
        condition_row = conditions_df[conditions_df['Sample Name'] == sample]
        speed = condition_row['Speed (mm/s)'].values[0]
        power = condition_row['Power (W)'].values[0]
        
        if (verbose):
            print(f"Extracted conditions - Speed: {speed}, Power: {power}")
        
        norm_speed = normalize_tensor(torch.tensor([speed]), global_speed_min, global_speed_max)
        norm_power = normalize_tensor(torch.tensor([power]), global_power_min, global_power_max)
        
        if (verbose):
            print(f"Normalized conditions - Speed: {norm_speed.item()}, Power: {norm_power.item()}")
        
        # Capture min and max values before normalization for boundary coordinates
        boundary_min_before = sample_boundary_coordinates[sample].min(dim=0).values
        boundary_max_before = sample_boundary_coordinates[sample].max(dim=0).values
        if (verbose):
            print(f"Boundary Min values before normalization: {boundary_min_before}")
        if (verbose):
            print(f"Boundary Max values before normalization: {boundary_max_before}")

        # Normalize coordinates
        boundary_coords = normalize_coordinates(sample_boundary_coordinates[sample], x_min, x_max, y_min, y_max, z_min, z_max)
        interior_coords = normalize_coordinates(sample_interior_coordinates[sample], x_min, x_max, y_min, y_max, z_min, z_max)

        # Capture min and max values after normalization for boundary coordinates
        boundary_min_after = boundary_coords.min(dim=0).values
        boundary_max_after = boundary_coords.max(dim=0).values
        if (verbose):
            print(f"Boundary Min values after normalization: {boundary_min_after}")
        if (verbose):
            print(f"Boundary Max values after normalization: {boundary_max_after}")
        
        if (verbose):
            print(f"Normalized coordinates. Shape (Boundary): {boundary_coords.shape}, Shape (Interior): {interior_coords.shape}")
        
        # Create condition tensors by repeating the speed and power values
        num_boundary_coords = len(boundary_coords)
        num_interior_coords = len(interior_coords)
        
        condition_boundary = torch.stack([norm_speed.repeat(num_boundary_coords), norm_power.repeat(num_boundary_coords)], dim=1)
        condition_interior = torch.stack([norm_speed.repeat(num_interior_coords), norm_power.repeat(num_interior_coords)], dim=1)
        
        # Concatenate coordinates and conditions
        boundary_data = torch.cat([boundary_coords, condition_boundary], dim=1)
        interior_data = torch.cat([interior_coords, condition_interior], dim=1)
        
        # Append to sample-specific data list
        if sample == exclude_sample:
            validation_data_list.append({'boundary': boundary_data, 'interior': interior_data, 'sample': sample})
        else:
            training_data_list.append({'boundary': boundary_data, 'interior': interior_data, 'sample': sample})
    
    # Create PyTorch Data Loaders using custom dataset
    train_loader = DataLoader(SampleSpecificDataset(training_data_list), batch_size=1, shuffle=True)
    val_loader = DataLoader(SampleSpecificDataset(validation_data_list), batch_size=1, shuffle=False)
    
    if (verbose):
        print("Created PyTorch Data Loaders.")
    
    return train_loader, val_loader

# %%
conditions_df['Sample Name'][0]
# Out:
# 'a'

# %%
# Create Data Loaders
train_loader, val_loader = create_data_loader(conditions_df['Sample Name'][0], global_x_max, global_x_min, global_y_max, 
                                              global_y_min, global_z_max, global_z_min,
                                              sample_coordinates, sample_boundary_coordinates,
                                              sample_interior_coordinates, conditions_df, data_frames)

# %%
def unnormalize_tensor(tensor, min_val, max_val):
    """
    Unnormalize a tensor from range [-1, 1] to original range.

    Parameters:
        tensor (torch.Tensor): The tensor to unnormalize.
        min_val (float): The minimum value for unnormalization.
        max_val (float): The maximum value for unnormalization.

    Returns:
        torch.Tensor: The unnormalized tensor.
    """
    return ((tensor + 1) / 2) * (max_val - min_val) + min_val

def unnormalize_coordinates(tensor, x_min, x_max, y_min, y_max, z_min, z_max):
    """
    Unnormalize the x, y, and z coordinates in a tensor to the original range.

    Parameters:
        tensor (torch.Tensor): The tensor to unnormalize. Shape: [N, 3]
        x_min, x_max (float): The minimum and maximum values for the x-coordinate.
        y_min, y_max (float): The minimum and maximum values for the y-coordinate.
        z_min, z_max (float): The minimum and maximum values for the z-coordinate.

    Returns:
        torch.Tensor: The unnormalized tensor. Shape: [N, 3]
    """
    unnormalized_tensor = tensor.clone()  # Create a new tensor
    unnormalized_tensor[:, 0] = ((tensor[:, 0] + 1) * (x_max - x_min) / 2) + x_min  # Unnormalize x
    unnormalized_tensor[:, 1] = ((tensor[:, 1] + 1) * (y_max - y_min) / 2) + y_min  # Unnormalize y
    unnormalized_tensor[:, 2] = ((tensor[:, 2] + 1) * (z_max - z_min) / 2) + z_min  # Unnormalize z
    
    return unnormalized_tensor

# %%
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D

# # Loop through each sample in the training DataLoader
# for i, sample_data in enumerate(train_loader, 0):
#     # Get the boundary and interior data for the current sample
#     boundary_data = sample_data['boundary'][0]
#     interior_data = sample_data['interior'][0]
#     sample_name = sample_data['sample'][0]

#     # Separate the coordinates and conditions
#     boundary_coords = boundary_data[:, :3]
#     boundary_conditions = boundary_data[:, 3:]

#     interior_coords = interior_data[:, :3]
#     interior_conditions = interior_data[:, 3:]

#     # Unnormalize coordinates
#     boundary_coords_unnorm = unnormalize_coordinates(boundary_coords, global_x_min, global_x_max, global_y_min, global_y_max, global_z_min, global_z_max)
#     interior_coords_unnorm = unnormalize_coordinates(interior_coords, global_x_min, global_x_max, global_y_min, global_y_max, global_z_min, global_z_max)

#     # Unnormalize conditions
#     speed_condition = unnormalize_tensor(boundary_conditions[0, 0], global_speed_min, global_speed_max)
#     power_condition = unnormalize_tensor(boundary_conditions[0, 1], global_power_min, global_power_max)

#     # Create the 3D scatter plot
#     fig = plt.figure(figsize=(10, 8))
#     ax = fig.add_subplot(111, projection='3d')
    
#     # Plot boundary coordinates in red
#     ax.scatter(boundary_coords_unnorm[:, 0], boundary_coords_unnorm[:, 1], boundary_coords_unnorm[:, 2], c='r', marker='o', alpha=0.5, label='Boundary Coordinates')
    
#     # Plot interior coordinates in blue
#     ax.scatter(interior_coords_unnorm[:, 0], interior_coords_unnorm[:, 1], interior_coords_unnorm[:, 2], c='b', marker='o', alpha=0.1, label='Interior Coordinates')

#     # Labels and title with conditions
#     ax.set_xlabel('X (um)')
#     ax.set_ylabel('Y (um)')
#     ax.set_zlabel('Z (um)')
#     ax.set_title(f'Sample {sample_name} - Speed: {speed_condition} mm/s, Power: {power_condition} W')
#     ax.legend()

#     plt.show()

# %%
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D

# # Loop through each batch in the training DataLoader
# for i, sample_data in enumerate(train_loader, 0):
#     # Get the boundary and interior data for the current sample
#     boundary_data = sample_data['boundary'][0]
#     interior_data = sample_data['interior'][0]
#     sample_name = sample_data['sample'][0]

#     # Separate the coordinates and conditions
#     boundary_coords = boundary_data[:, :3]
#     boundary_conditions = boundary_data[:, 3:]

#     interior_coords = interior_data[:, :3]
#     interior_conditions = interior_data[:, 3:]

#     # Extract conditions (no need to unnormalize here)
#     speed_condition = boundary_conditions[0, 0]
#     power_condition = boundary_conditions[0, 1]

#     # Create the 3D scatter plot
#     fig = plt.figure(figsize=(10, 8))
#     ax = fig.add_subplot(111, projection='3d')
    
#     # Plot boundary coordinates in red
#     ax.scatter(boundary_coords[:, 0], boundary_coords[:, 1], boundary_coords[:, 2], c='r', marker='o', alpha=0.5, label='Boundary Coordinates (Normalized)')
    
#     # Plot interior coordinates in blue
#     ax.scatter(interior_coords[:, 0], interior_coords[:, 1], interior_coords[:, 2], c='b', marker='o', alpha=0.1, label='Interior Coordinates (Normalized)')

#     # Labels and title with conditions
#     ax.set_xlabel('X (Normalized)')
#     ax.set_ylabel('Y (Normalized)')
#     ax.set_zlabel('Z (Normalized)')
#     ax.set_title(f'Sample {sample_name} - Speed: {speed_condition:.4f} (Normalized), Power: {power_condition:.4f} (Normalized)')
#     ax.legend()

#     plt.show()

# %%
# Initialize Neural Networks
temp_net = TempFieldNN(300.0).to(device).train()

# Split the model across two GPUs
#temp_net = torch.nn.DataParallel(temp_net, device_ids=[0, 1])
temp_net
# Out:
# TempFieldNN(
#   (layer1): Linear(in_features=5, out_features=5000, bias=True)
#   (layer2): Linear(in_features=5000, out_features=5000, bias=True)
#   (layer_out): Linear(in_features=5000, out_features=1, bias=True)
# )

# %%
from torch.optim import LBFGS, Adam

# Initialize Optimizers
params = list(temp_net.parameters())
optimizer_adam = Adam(params, lr=1e-3)
optimizer_lbfgs = LBFGS(params, line_search_fn="strong_wolfe")

# List of all sample names
all_samples = conditions_df['Sample Name'].tolist()

exclude_sample = all_samples[0]

print(f"Excluding sample: {exclude_sample} for validation.")

# Create Data Loaders
train_loader, val_loader = create_data_loader(exclude_sample, global_x_max, global_x_min, global_y_max, 
                                              global_y_min, global_z_max, global_z_min,
                                              sample_coordinates, sample_boundary_coordinates,
                                              sample_interior_coordinates, conditions_df, data_frames)

for i, sample_data in enumerate(train_loader, 0):
    boundary_data = sample_data['boundary'][0].to(device)
    interior_data = sample_data['interior'][0].to(device)
    sample_name = sample_data['sample'][0]

    # Unnormalize conditions
    speed = unnormalize_tensor(interior_data[:, 3], global_speed_min, global_speed_max)
    power = unnormalize_tensor(interior_data[:, 4], global_power_min, global_power_max)

    # Unnormalize coordinates
    interior_coords_unnorm = unnormalize_coordinates(interior_data[:, :3], global_x_min, 
                                                     global_x_max, global_y_min, 
                                                     global_y_max, global_z_min, global_z_max)

    print(f"Processing sample: {sample_name}")

    # Set the coordinates to require gradient computation
    boundary_data.requires_grad = True
    interior_data.requires_grad = True

    # Compute heat source for the interior coordinates
    Q_values_interior = heat_source(interior_coords_unnorm / 1000, power, spot_radius, eta)  
    break

# Initialize iteration counter
iteration = 0

# Inner training loop
for epoch in range(num_epochs):  
    loss_epoch = 0.0
    
    # Select the optimizer based on the iteration
    if iteration < 1000:
        optimizer = optimizer_adam
    else:
        optimizer = optimizer_lbfgs
          

    def closure():
        optimizer.zero_grad()
        # Initialize total loss
        total_loss = 0.0

        # Temperature Boundary Computations
        temp_at_boundary = temp_net(boundary_data)

        # Compute temperature gradients at the boundary
        temp_gradients_boundary = torch.autograd.grad(
            temp_at_boundary.sum(), boundary_data,
            create_graph=True, retain_graph=True
        )[0][:, :3]

        # Compute the adiabatic residual at the boundary
        adiabatic_residual_boundary = torch.mean(temp_gradients_boundary ** 2)
        total_loss += adiabatic_residual_boundary

        # Compute temperature residual at the boundary
        temp_residual_boundary = temp_at_boundary - T_amb
        temp_residual_boundary_mean = torch.mean(temp_residual_boundary ** 2)
        total_loss += temp_residual_boundary_mean

        # Temperature Interior Computations
        temp_at_interior = temp_net(interior_data)

        # Compute temperature gradients at the interior
        temp_gradients_interior = torch.autograd.grad(
            temp_at_interior.sum(), interior_data,
            create_graph=True, retain_graph=True
        )[0]

        # Compute second partial derivatives (Laplacian components) for temperature at the interior
        temp_gradients_interior_second = torch.autograd.grad(
            temp_gradients_interior.sum(), interior_data,
            create_graph=True, retain_graph=True
        )[0][:, :3]

        # Compute the Laplacian of temperature at the interior
        temp_laplacian_interior = temp_gradients_interior_second.sum(dim=1)

        # Compute the heat equation residual
        heat_equation_residual = (
            rho * Cp * temp_gradients_interior[:, 0] * speed.flatten()
            + kappa * temp_laplacian_interior + Q_values_interior
        )

        # Compute the mean square of the heat equation residual
        heat_equation_residual_mean = torch.mean(heat_equation_residual ** 2)

        # Add heat equation residual to the total loss
        total_loss += heat_equation_residual_mean

        # Add Penalty for Negative Temperatures
        negative_temp_penalty = torch.nn.ReLU()(-temp_at_interior)
        negative_temp_penalty_mean = torch.mean(negative_temp_penalty ** 2)

        # Add negative temperature penalty to the total loss
        total_loss += negative_temp_penalty_mean

        total_loss.backward()
        return total_loss

    # Backward pass and optimization using L-BFGS
    loss = optimizer.step(closure)
    loss_epoch += loss.item()
    
    # Increment the iteration counter
    iteration += 1

    #print(f"Epoch: {epoch}, Iteration: {iteration}, Sample: {sample_name}, Loss: {loss.item()}")


    print(f"DONE with Epoch: {epoch}, Loss EPOCH: {loss_epoch}")  
print(f"Finished LOOCV for excluded sample: {exclude_sample}")

print("Finished all LOOCV cycles.")
# Out:
# Excluding sample: a for validation.
# Processing sample: f
# DONE with Epoch: 0, Loss EPOCH: 31278462.0
# DONE with Epoch: 1, Loss EPOCH: 31261070.0
# DONE with Epoch: 2, Loss EPOCH: 31257190.0
# DONE with Epoch: 3, Loss EPOCH: 31253918.0
# DONE with Epoch: 4, Loss EPOCH: 31248318.0
# DONE with Epoch: 5, Loss EPOCH: 31239818.0
# DONE with Epoch: 6, Loss EPOCH: 31232498.0
# DONE with Epoch: 7, Loss EPOCH: 31226884.0
# DONE with Epoch: 8, Loss EPOCH: 31219878.0
# DONE with Epoch: 9, Loss EPOCH: 31212122.0
# DONE with Epoch: 10, Loss EPOCH: 31205688.0
# DONE with Epoch: 11, Loss EPOCH: 31199816.0
# DONE with Epoch: 12, Loss EPOCH: 31193024.0
# DONE with Epoch: 13, Loss EPOCH: 31185806.0
# DONE with Epoch: 14, Loss EPOCH: 31179296.0
# DONE with Epoch: 15, Loss EPOCH: 31173208.0
# DONE with Epoch: 16, Loss EPOCH: 31166710.0
# DONE with Epoch: 17, Loss EPOCH: 31160018.0
# DONE with Epoch: 18, Loss EPOCH: 31153732.0
# DONE with Epoch: 19, Loss EPOCH: 31147770.0
# DONE with Epoch: 20, Loss EPOCH: 31141660.0
# DONE with Epoch: 21, Loss EPOCH: 31135372.0
# DONE with Epoch: 22, Loss EPOCH: 31129242.0
# DONE with Epoch: 23, Loss EPOCH: 31123378.0
# DONE with Epoch: 24, Loss EPOCH: 31117558.0
# DONE with Epoch: 25, Loss EPOCH: 31111722.0
# DONE with Epoch: 26, Loss EPOCH: 31105934.0
# DONE with Epoch: 27, Loss EPOCH: 31100256.0
# DONE with Epoch: 28, Loss EPOCH: 31094676.0
# DONE with Epoch: 29, Loss EPOCH: 31089162.0
# DONE with Epoch: 30, Loss EPOCH: 31083736.0
# DONE with Epoch: 31, Loss EPOCH: 31078368.0
# DONE with Epoch: 32, Loss EPOCH: 31073022.0
# DONE with Epoch: 33, Loss EPOCH: 31067742.0
# DONE with Epoch: 34, Loss EPOCH: 31062526.0
# DONE with Epoch: 35, Loss EPOCH: 31057372.0
# DONE with Epoch: 36, Loss EPOCH: 31052298.0
# DONE with Epoch: 37, Loss EPOCH: 31047380.0
# DONE with Epoch: 38, Loss EPOCH: 31042210.0
# DONE with Epoch: 39, Loss EPOCH: 31037398.0
# DONE with Epoch: 40, Loss EPOCH: 31032290.0
# DONE with Epoch: 41, Loss EPOCH: 31027570.0
# DONE with Epoch: 42, Loss EPOCH: 31022534.0
# DONE with Epoch: 43, Loss EPOCH: 31017958.0
# DONE with Epoch: 44, Loss EPOCH: 31012942.0
# DONE with Epoch: 45, Loss EPOCH: 31008274.0
# DONE with Epoch: 46, Loss EPOCH: 31003350.0
# DONE with Epoch: 47, Loss EPOCH: 30998556.0
# DONE with Epoch: 48, Loss EPOCH: 30994022.0
# DONE with Epoch: 49, Loss EPOCH: 30988726.0
# DONE with Epoch: 50, Loss EPOCH: 30984196.0
# DONE with Epoch: 51, Loss EPOCH: 30978882.0
# DONE with Epoch: 52, Loss EPOCH: 30973662.0
# DONE with Epoch: 53, Loss EPOCH: 30968512.0
# DONE with Epoch: 54, Loss EPOCH: 30962682.0
# DONE with Epoch: 55, Loss EPOCH: 30957302.0
# DONE with Epoch: 56, Loss EPOCH: 30950664.0
# DONE with Epoch: 57, Loss EPOCH: 30943912.0
# DONE with Epoch: 58, Loss EPOCH: 30934668.0
# DONE with Epoch: 59, Loss EPOCH: 30927552.0
# DONE with Epoch: 60, Loss EPOCH: 30914580.0
# DONE with Epoch: 61, Loss EPOCH: 30904028.0
# DONE with Epoch: 62, Loss EPOCH: 30890526.0
# DONE with Epoch: 63, Loss EPOCH: 30871882.0
# DONE with Epoch: 64, Loss EPOCH: 30848576.0
# DONE with Epoch: 65, Loss EPOCH: 30817940.0
# DONE with Epoch: 66, Loss EPOCH: 30774746.0
# DONE with Epoch: 67, Loss EPOCH: 30728684.0
# DONE with Epoch: 68, Loss EPOCH: 30667930.0
# DONE with Epoch: 69, Loss EPOCH: 30649138.0
# DONE with Epoch: 70, Loss EPOCH: 30563458.0
# DONE with Epoch: 71, Loss EPOCH: 30524036.0
# DONE with Epoch: 72, Loss EPOCH: 30487898.0
# DONE with Epoch: 73, Loss EPOCH: 30409700.0
# DONE with Epoch: 74, Loss EPOCH: 30404060.0
# DONE with Epoch: 75, Loss EPOCH: 30332376.0
# DONE with Epoch: 76, Loss EPOCH: 30289112.0
# DONE with Epoch: 77, Loss EPOCH: 30251778.0
# DONE with Epoch: 78, Loss EPOCH: 30148434.0
# DONE with Epoch: 79, Loss EPOCH: 30115494.0
# DONE with Epoch: 80, Loss EPOCH: 30061530.0
# DONE with Epoch: 81, Loss EPOCH: 29985540.0
# DONE with Epoch: 82, Loss EPOCH: 29933784.0
# DONE with Epoch: 83, Loss EPOCH: 29844440.0
# DONE with Epoch: 84, Loss EPOCH: 29825440.0
# DONE with Epoch: 85, Loss EPOCH: 29743986.0
# DONE with Epoch: 86, Loss EPOCH: 29698490.0
# DONE with Epoch: 87, Loss EPOCH: 29606174.0
# DONE with Epoch: 88, Loss EPOCH: 29568408.0
# DONE with Epoch: 89, Loss EPOCH: 29482976.0
# DONE with Epoch: 90, Loss EPOCH: 29423298.0
# DONE with Epoch: 91, Loss EPOCH: 29313064.0
# DONE with Epoch: 92, Loss EPOCH: 29276684.0
# DONE with Epoch: 93, Loss EPOCH: 29142258.0
# DONE with Epoch: 94, Loss EPOCH: 29122434.0
# DONE with Epoch: 95, Loss EPOCH: 28970250.0
# DONE with Epoch: 96, Loss EPOCH: 28940588.0
# DONE with Epoch: 97, Loss EPOCH: 28728262.0
# DONE with Epoch: 98, Loss EPOCH: 28713454.0
# DONE with Epoch: 99, Loss EPOCH: 28445250.0
# DONE with Epoch: 100, Loss EPOCH: 28437118.0
# DONE with Epoch: 101, Loss EPOCH: 28108236.0
# DONE with Epoch: 102, Loss EPOCH: 28043352.0
# DONE with Epoch: 103, Loss EPOCH: 27712324.0
# DONE with Epoch: 104, Loss EPOCH: 27620016.0
# DONE with Epoch: 105, Loss EPOCH: 27345630.0
# DONE with Epoch: 106, Loss EPOCH: 27343396.0
# DONE with Epoch: 107, Loss EPOCH: 26971726.0
# DONE with Epoch: 108, Loss EPOCH: 26960642.0
# DONE with Epoch: 109, Loss EPOCH: 26320786.0
# DONE with Epoch: 110, Loss EPOCH: 26252120.0
# DONE with Epoch: 111, Loss EPOCH: 25832380.0
# DONE with Epoch: 112, Loss EPOCH: 25606282.0
# DONE with Epoch: 113, Loss EPOCH: 25262908.0
# DONE with Epoch: 114, Loss EPOCH: 25048910.0
# DONE with Epoch: 115, Loss EPOCH: 24659138.0
# DONE with Epoch: 116, Loss EPOCH: 24700122.0
# DONE with Epoch: 117, Loss EPOCH: 24299130.0
# DONE with Epoch: 118, Loss EPOCH: 24544870.0
# DONE with Epoch: 119, Loss EPOCH: 23289796.0
# DONE with Epoch: 120, Loss EPOCH: 23637228.0
# DONE with Epoch: 121, Loss EPOCH: 22666012.0
# DONE with Epoch: 122, Loss EPOCH: 22657466.0
# DONE with Epoch: 123, Loss EPOCH: 21987768.0
# DONE with Epoch: 124, Loss EPOCH: 21816572.0
# DONE with Epoch: 125, Loss EPOCH: 21080480.0
# DONE with Epoch: 126, Loss EPOCH: 20946868.0
# DONE with Epoch: 127, Loss EPOCH: 20311542.0
# DONE with Epoch: 128, Loss EPOCH: 20168204.0
# DONE with Epoch: 129, Loss EPOCH: 19856180.0
# DONE with Epoch: 130, Loss EPOCH: 19947148.0
# DONE with Epoch: 131, Loss EPOCH: 19029292.0
# DONE with Epoch: 132, Loss EPOCH: 19252882.0
# DONE with Epoch: 133, Loss EPOCH: 17922394.0
# DONE with Epoch: 134, Loss EPOCH: 18012662.0
# DONE with Epoch: 135, Loss EPOCH: 17202362.0
# DONE with Epoch: 136, Loss EPOCH: 16974526.0
# DONE with Epoch: 137, Loss EPOCH: 16433831.0
# DONE with Epoch: 138, Loss EPOCH: 16195293.0
# DONE with Epoch: 139, Loss EPOCH: 15619644.0
# DONE with Epoch: 140, Loss EPOCH: 15605268.0
# DONE with Epoch: 141, Loss EPOCH: 14926918.0
# DONE with Epoch: 142, Loss EPOCH: 15031106.0
# DONE with Epoch: 143, Loss EPOCH: 14256485.0
# DONE with Epoch: 144, Loss EPOCH: 14209385.0
# DONE with Epoch: 145, Loss EPOCH: 13240789.0
# DONE with Epoch: 146, Loss EPOCH: 13106172.0
# DONE with Epoch: 147, Loss EPOCH: 12401576.0
# DONE with Epoch: 148, Loss EPOCH: 12153944.0
# DONE with Epoch: 149, Loss EPOCH: 11659009.0
# DONE with Epoch: 150, Loss EPOCH: 11417232.0
# DONE with Epoch: 151, Loss EPOCH: 11107615.0
# DONE with Epoch: 152, Loss EPOCH: 11078223.0
# DONE with Epoch: 153, Loss EPOCH: 11073684.0
# DONE with Epoch: 154, Loss EPOCH: 10927023.0
# DONE with Epoch: 155, Loss EPOCH: 10175449.0
# DONE with Epoch: 156, Loss EPOCH: 9796983.0
# DONE with Epoch: 157, Loss EPOCH: 9039140.0
# DONE with Epoch: 158, Loss EPOCH: 8884365.0
# DONE with Epoch: 159, Loss EPOCH: 8795379.0
# DONE with Epoch: 160, Loss EPOCH: 8522879.0
# DONE with Epoch: 161, Loss EPOCH: 8572013.0
# DONE with Epoch: 162, Loss EPOCH: 8409946.0
# DONE with Epoch: 163, Loss EPOCH: 8045301.0
# DONE with Epoch: 164, Loss EPOCH: 7375930.0
# DONE with Epoch: 165, Loss EPOCH: 7003212.5
# DONE with Epoch: 166, Loss EPOCH: 6820410.5
# DONE with Epoch: 167, Loss EPOCH: 6739381.0
# DONE with Epoch: 168, Loss EPOCH: 6729653.5
# DONE with Epoch: 169, Loss EPOCH: 6543212.5
# DONE with Epoch: 170, Loss EPOCH: 6087524.5
# DONE with Epoch: 171, Loss EPOCH: 5640994.5
# DONE with Epoch: 172, Loss EPOCH: 5424271.0
# DONE with Epoch: 173, Loss EPOCH: 5317848.5
# DONE with Epoch: 174, Loss EPOCH: 5331340.0
# DONE with Epoch: 175, Loss EPOCH: 5431849.5
# DONE with Epoch: 176, Loss EPOCH: 5653630.5
# DONE with Epoch: 177, Loss EPOCH: 4997497.5
# DONE with Epoch: 178, Loss EPOCH: 4506218.5
# DONE with Epoch: 179, Loss EPOCH: 4322556.5
# DONE with Epoch: 180, Loss EPOCH: 4449489.5
# DONE with Epoch: 181, Loss EPOCH: 4571764.0
# DONE with Epoch: 182, Loss EPOCH: 4148677.5
# DONE with Epoch: 183, Loss EPOCH: 3806869.0
# DONE with Epoch: 184, Loss EPOCH: 3586496.5
# DONE with Epoch: 185, Loss EPOCH: 3632676.75
# DONE with Epoch: 186, Loss EPOCH: 3742739.25
# DONE with Epoch: 187, Loss EPOCH: 3718657.25
# DONE with Epoch: 188, Loss EPOCH: 3841358.0
# DONE with Epoch: 189, Loss EPOCH: 3360350.25
# DONE with Epoch: 190, Loss EPOCH: 3072098.25
# DONE with Epoch: 191, Loss EPOCH: 3029032.75
# DONE with Epoch: 192, Loss EPOCH: 3128618.25
# DONE with Epoch: 193, Loss EPOCH: 3184861.25
# DONE with Epoch: 194, Loss EPOCH: 2877169.5
# DONE with Epoch: 195, Loss EPOCH: 2693603.75
# DONE with Epoch: 196, Loss EPOCH: 2599377.0
# DONE with Epoch: 197, Loss EPOCH: 2603182.0
# DONE with Epoch: 198, Loss EPOCH: 2696106.5
# DONE with Epoch: 199, Loss EPOCH: 2680004.25
# DONE with Epoch: 200, Loss EPOCH: 2882249.0
# DONE with Epoch: 201, Loss EPOCH: 2674073.25
# DONE with Epoch: 202, Loss EPOCH: 2425036.5
# DONE with Epoch: 203, Loss EPOCH: 2190093.75
# DONE with Epoch: 204, Loss EPOCH: 2237023.25
# DONE with Epoch: 205, Loss EPOCH: 2368980.75
# DONE with Epoch: 206, Loss EPOCH: 2320675.5
# DONE with Epoch: 207, Loss EPOCH: 2189998.25
# DONE with Epoch: 208, Loss EPOCH: 2023267.25
# DONE with Epoch: 209, Loss EPOCH: 1983427.625
# DONE with Epoch: 210, Loss EPOCH: 1982546.375
# DONE with Epoch: 211, Loss EPOCH: 2018058.0
# DONE with Epoch: 212, Loss EPOCH: 2096076.875
# DONE with Epoch: 213, Loss EPOCH: 2088171.25
# DONE with Epoch: 214, Loss EPOCH: 2085504.75
# DONE with Epoch: 215, Loss EPOCH: 1892953.25
# DONE with Epoch: 216, Loss EPOCH: 1746571.75
# DONE with Epoch: 217, Loss EPOCH: 1690400.75
# DONE with Epoch: 218, Loss EPOCH: 1763236.0
# DONE with Epoch: 219, Loss EPOCH: 1852747.875
# DONE with Epoch: 220, Loss EPOCH: 1763641.25
# DONE with Epoch: 221, Loss EPOCH: 1720229.0
# DONE with Epoch: 222, Loss EPOCH: 1649306.0
# DONE with Epoch: 223, Loss EPOCH: 1639649.5
# DONE with Epoch: 224, Loss EPOCH: 1612901.625
# DONE with Epoch: 225, Loss EPOCH: 1553171.875
# DONE with Epoch: 226, Loss EPOCH: 1509089.5
# DONE with Epoch: 227, Loss EPOCH: 1510124.75
# DONE with Epoch: 228, Loss EPOCH: 1567265.125
# DONE with Epoch: 229, Loss EPOCH: 1601279.25
# DONE with Epoch: 230, Loss EPOCH: 1622300.625
# DONE with Epoch: 231, Loss EPOCH: 1627996.375
# DONE with Epoch: 232, Loss EPOCH: 1674667.5
# DONE with Epoch: 233, Loss EPOCH: 1622190.0
# DONE with Epoch: 234, Loss EPOCH: 1572728.75
# DONE with Epoch: 235, Loss EPOCH: 1418024.5
# DONE with Epoch: 236, Loss EPOCH: 1367669.125
# DONE with Epoch: 237, Loss EPOCH: 1425506.0
# DONE with Epoch: 238, Loss EPOCH: 1476304.375
# DONE with Epoch: 239, Loss EPOCH: 1430258.75
# DONE with Epoch: 240, Loss EPOCH: 1308780.125
# DONE with Epoch: 241, Loss EPOCH: 1279761.75
# DONE with Epoch: 242, Loss EPOCH: 1313388.875
# DONE with Epoch: 243, Loss EPOCH: 1345211.0
# DONE with Epoch: 244, Loss EPOCH: 1383969.75
# DONE with Epoch: 245, Loss EPOCH: 1322593.25
# DONE with Epoch: 246, Loss EPOCH: 1309708.5
# DONE with Epoch: 247, Loss EPOCH: 1316194.25
# DONE with Epoch: 248, Loss EPOCH: 1296936.75
# DONE with Epoch: 249, Loss EPOCH: 1256102.25
# DONE with Epoch: 250, Loss EPOCH: 1191772.5
# DONE with Epoch: 251, Loss EPOCH: 1150941.25
# DONE with Epoch: 252, Loss EPOCH: 1156649.25
# DONE with Epoch: 253, Loss EPOCH: 1187794.75
# DONE with Epoch: 254, Loss EPOCH: 1221368.375
# DONE with Epoch: 255, Loss EPOCH: 1253086.75
# DONE with Epoch: 256, Loss EPOCH: 1279874.375
# DONE with Epoch: 257, Loss EPOCH: 1390009.25
# DONE with Epoch: 258, Loss EPOCH: 1447023.875
# DONE with Epoch: 259, Loss EPOCH: 1489461.5
# DONE with Epoch: 260, Loss EPOCH: 1209471.375
# DONE with Epoch: 261, Loss EPOCH: 1094565.25
# DONE with Epoch: 262, Loss EPOCH: 1230392.0
# DONE with Epoch: 263, Loss EPOCH: 1255420.0
# DONE with Epoch: 264, Loss EPOCH: 1123273.0
# DONE with Epoch: 265, Loss EPOCH: 1040718.375
# DONE with Epoch: 266, Loss EPOCH: 1133497.0
# DONE with Epoch: 267, Loss EPOCH: 1195595.5
# DONE with Epoch: 268, Loss EPOCH: 1107581.625
# DONE with Epoch: 269, Loss EPOCH: 1031594.75
# DONE with Epoch: 270, Loss EPOCH: 1040153.75
# DONE with Epoch: 271, Loss EPOCH: 1087046.25
# DONE with Epoch: 272, Loss EPOCH: 1129500.625
# DONE with Epoch: 273, Loss EPOCH: 1039290.125
# DONE with Epoch: 274, Loss EPOCH: 986560.25
# DONE with Epoch: 275, Loss EPOCH: 998101.4375
# DONE with Epoch: 276, Loss EPOCH: 1037022.25
# DONE with Epoch: 277, Loss EPOCH: 1051029.375
# DONE with Epoch: 278, Loss EPOCH: 997725.0
# DONE with Epoch: 279, Loss EPOCH: 933857.75
# DONE with Epoch: 280, Loss EPOCH: 920062.5
# DONE with Epoch: 281, Loss EPOCH: 966573.25
# DONE with Epoch: 282, Loss EPOCH: 1034389.875
# DONE with Epoch: 283, Loss EPOCH: 1048625.875
# DONE with Epoch: 284, Loss EPOCH: 1061217.75
# DONE with Epoch: 285, Loss EPOCH: 1100720.5
# DONE with Epoch: 286, Loss EPOCH: 1086192.125
# DONE with Epoch: 287, Loss EPOCH: 1098822.5
# DONE with Epoch: 288, Loss EPOCH: 972706.0625
# DONE with Epoch: 289, Loss EPOCH: 865489.625
# DONE with Epoch: 290, Loss EPOCH: 917641.25
# DONE with Epoch: 291, Loss EPOCH: 977196.625
# DONE with Epoch: 292, Loss EPOCH: 916496.8125
# DONE with Epoch: 293, Loss EPOCH: 824204.8125
# DONE with Epoch: 294, Loss EPOCH: 840342.5
# DONE with Epoch: 295, Loss EPOCH: 896395.0
# DONE with Epoch: 296, Loss EPOCH: 896503.75
# DONE with Epoch: 297, Loss EPOCH: 853298.1875
# DONE with Epoch: 298, Loss EPOCH: 812649.375
# DONE with Epoch: 299, Loss EPOCH: 806655.25
# DONE with Epoch: 300, Loss EPOCH: 822114.375
# DONE with Epoch: 301, Loss EPOCH: 821356.875
# DONE with Epoch: 302, Loss EPOCH: 823420.1875
# DONE with Epoch: 303, Loss EPOCH: 789815.625
# DONE with Epoch: 304, Loss EPOCH: 771178.875
# DONE with Epoch: 305, Loss EPOCH: 774093.25
# DONE with Epoch: 306, Loss EPOCH: 819900.875
# DONE with Epoch: 307, Loss EPOCH: 903890.375
# DONE with Epoch: 308, Loss EPOCH: 894044.625
# DONE with Epoch: 309, Loss EPOCH: 846572.8125
# DONE with Epoch: 310, Loss EPOCH: 761764.4375
# DONE with Epoch: 311, Loss EPOCH: 723713.25
# DONE with Epoch: 312, Loss EPOCH: 717472.875
# DONE with Epoch: 313, Loss EPOCH: 743964.625
# DONE with Epoch: 314, Loss EPOCH: 752476.625
# DONE with Epoch: 315, Loss EPOCH: 732883.125
# DONE with Epoch: 316, Loss EPOCH: 687167.9375
# DONE with Epoch: 317, Loss EPOCH: 660967.5625
# DONE with Epoch: 318, Loss EPOCH: 678577.0
# DONE with Epoch: 319, Loss EPOCH: 691515.0
# DONE with Epoch: 320, Loss EPOCH: 689404.5625
# DONE with Epoch: 321, Loss EPOCH: 670947.8125
# DONE with Epoch: 322, Loss EPOCH: 654409.0625
# DONE with Epoch: 323, Loss EPOCH: 635934.5
# DONE with Epoch: 324, Loss EPOCH: 617710.9375
# DONE with Epoch: 325, Loss EPOCH: 605063.75
# DONE with Epoch: 326, Loss EPOCH: 608691.625
# DONE with Epoch: 327, Loss EPOCH: 647274.6875
# DONE with Epoch: 328, Loss EPOCH: 738504.6875
# DONE with Epoch: 329, Loss EPOCH: 866783.5
# DONE with Epoch: 330, Loss EPOCH: 1053453.75
# DONE with Epoch: 331, Loss EPOCH: 1262072.25
# DONE with Epoch: 332, Loss EPOCH: 931253.5
# DONE with Epoch: 333, Loss EPOCH: 855768.1875
# DONE with Epoch: 334, Loss EPOCH: 1003431.5625
# DONE with Epoch: 335, Loss EPOCH: 777126.1875
# DONE with Epoch: 336, Loss EPOCH: 689855.0
# DONE with Epoch: 337, Loss EPOCH: 835697.5625
# DONE with Epoch: 338, Loss EPOCH: 816327.9375
# DONE with Epoch: 339, Loss EPOCH: 627874.5625
# DONE with Epoch: 340, Loss EPOCH: 642476.3125
# DONE with Epoch: 341, Loss EPOCH: 804816.9375
# DONE with Epoch: 342, Loss EPOCH: 763167.25
# DONE with Epoch: 343, Loss EPOCH: 636666.875
# DONE with Epoch: 344, Loss EPOCH: 543342.4375
# DONE with Epoch: 345, Loss EPOCH: 604056.6875
# DONE with Epoch: 346, Loss EPOCH: 670606.125
# DONE with Epoch: 347, Loss EPOCH: 646874.875
# DONE with Epoch: 348, Loss EPOCH: 570860.4375
# DONE with Epoch: 349, Loss EPOCH: 516410.0625
# DONE with Epoch: 350, Loss EPOCH: 533305.0625
# DONE with Epoch: 351, Loss EPOCH: 589959.375
# DONE with Epoch: 352, Loss EPOCH: 607998.125
# DONE with Epoch: 353, Loss EPOCH: 577058.9375
# DONE with Epoch: 354, Loss EPOCH: 649733.375
# DONE with Epoch: 355, Loss EPOCH: 840632.875
# DONE with Epoch: 356, Loss EPOCH: 1211844.125
# DONE with Epoch: 357, Loss EPOCH: 965933.0625
# DONE with Epoch: 358, Loss EPOCH: 633314.8125
# DONE with Epoch: 359, Loss EPOCH: 601839.875
# DONE with Epoch: 360, Loss EPOCH: 814832.75
# DONE with Epoch: 361, Loss EPOCH: 713379.9375
# DONE with Epoch: 362, Loss EPOCH: 520888.53125
# DONE with Epoch: 363, Loss EPOCH: 676717.625
# DONE with Epoch: 364, Loss EPOCH: 649168.9375
# DONE with Epoch: 365, Loss EPOCH: 523818.875
# DONE with Epoch: 366, Loss EPOCH: 538770.25
# DONE with Epoch: 367, Loss EPOCH: 593211.1875
# DONE with Epoch: 368, Loss EPOCH: 540113.9375
# DONE with Epoch: 369, Loss EPOCH: 484118.03125
# DONE with Epoch: 370, Loss EPOCH: 455639.125
# DONE with Epoch: 371, Loss EPOCH: 525371.8125
# DONE with Epoch: 372, Loss EPOCH: 531447.6875
# DONE with Epoch: 373, Loss EPOCH: 475665.65625
# DONE with Epoch: 374, Loss EPOCH: 486301.5625
# DONE with Epoch: 375, Loss EPOCH: 416111.90625
# DONE with Epoch: 376, Loss EPOCH: 453957.1875
# DONE with Epoch: 377, Loss EPOCH: 457659.3125
# DONE with Epoch: 378, Loss EPOCH: 461866.78125
# DONE with Epoch: 379, Loss EPOCH: 471196.59375
# DONE with Epoch: 380, Loss EPOCH: 469845.6875
# DONE with Epoch: 381, Loss EPOCH: 510623.375
# DONE with Epoch: 382, Loss EPOCH: 552426.875
# DONE with Epoch: 383, Loss EPOCH: 620506.6875
# DONE with Epoch: 384, Loss EPOCH: 532367.625
# DONE with Epoch: 385, Loss EPOCH: 437685.25
# DONE with Epoch: 386, Loss EPOCH: 403473.25
# DONE with Epoch: 387, Loss EPOCH: 438050.6875
# DONE with Epoch: 388, Loss EPOCH: 445805.40625
# DONE with Epoch: 389, Loss EPOCH: 403154.65625
# DONE with Epoch: 390, Loss EPOCH: 369779.375
# DONE with Epoch: 391, Loss EPOCH: 392852.65625
# DONE with Epoch: 392, Loss EPOCH: 398225.1875
# DONE with Epoch: 393, Loss EPOCH: 390021.5625
# DONE with Epoch: 394, Loss EPOCH: 362942.375
# DONE with Epoch: 395, Loss EPOCH: 358080.875
# DONE with Epoch: 396, Loss EPOCH: 362535.46875
# DONE with Epoch: 397, Loss EPOCH: 378246.28125
# DONE with Epoch: 398, Loss EPOCH: 375179.40625
# DONE with Epoch: 399, Loss EPOCH: 347233.1875
# DONE with Epoch: 400, Loss EPOCH: 327181.8125
# DONE with Epoch: 401, Loss EPOCH: 322063.375
# DONE with Epoch: 402, Loss EPOCH: 324305.15625
# DONE with Epoch: 403, Loss EPOCH: 337489.4375
# DONE with Epoch: 404, Loss EPOCH: 356238.46875
# DONE with Epoch: 405, Loss EPOCH: 376967.90625
# DONE with Epoch: 406, Loss EPOCH: 397225.6875
# DONE with Epoch: 407, Loss EPOCH: 401649.3125
# DONE with Epoch: 408, Loss EPOCH: 397560.5
# DONE with Epoch: 409, Loss EPOCH: 396009.9375
# DONE with Epoch: 410, Loss EPOCH: 439594.625
# DONE with Epoch: 411, Loss EPOCH: 514791.1875
# DONE with Epoch: 412, Loss EPOCH: 622985.4375
# DONE with Epoch: 413, Loss EPOCH: 513921.9375
# DONE with Epoch: 414, Loss EPOCH: 366280.75
# DONE with Epoch: 415, Loss EPOCH: 346038.28125
# DONE with Epoch: 416, Loss EPOCH: 397335.71875
# DONE with Epoch: 417, Loss EPOCH: 388644.625
# DONE with Epoch: 418, Loss EPOCH: 324386.78125
# DONE with Epoch: 419, Loss EPOCH: 349225.8125
# DONE with Epoch: 420, Loss EPOCH: 382360.96875
# DONE with Epoch: 421, Loss EPOCH: 310429.0
# DONE with Epoch: 422, Loss EPOCH: 269789.75
# DONE with Epoch: 423, Loss EPOCH: 314489.625
# DONE with Epoch: 424, Loss EPOCH: 344496.03125
# DONE with Epoch: 425, Loss EPOCH: 325365.9375
# DONE with Epoch: 426, Loss EPOCH: 278095.0
# DONE with Epoch: 427, Loss EPOCH: 262645.3125
# DONE with Epoch: 428, Loss EPOCH: 281482.3125
# DONE with Epoch: 429, Loss EPOCH: 306304.28125
# DONE with Epoch: 430, Loss EPOCH: 326984.0625
# DONE with Epoch: 431, Loss EPOCH: 291399.65625
# DONE with Epoch: 432, Loss EPOCH: 262230.34375
# DONE with Epoch: 433, Loss EPOCH: 242071.96875
# DONE with Epoch: 434, Loss EPOCH: 239373.1875
# DONE with Epoch: 435, Loss EPOCH: 253681.1875
# DONE with Epoch: 436, Loss EPOCH: 266232.65625
# DONE with Epoch: 437, Loss EPOCH: 268672.03125
# DONE with Epoch: 438, Loss EPOCH: 255321.25
# DONE with Epoch: 439, Loss EPOCH: 240613.046875
# DONE with Epoch: 440, Loss EPOCH: 227917.875
# DONE with Epoch: 441, Loss EPOCH: 227636.71875
# DONE with Epoch: 442, Loss EPOCH: 251070.484375
# DONE with Epoch: 443, Loss EPOCH: 325180.03125
# DONE with Epoch: 444, Loss EPOCH: 438184.6875
# DONE with Epoch: 445, Loss EPOCH: 495969.71875
# DONE with Epoch: 446, Loss EPOCH: 463757.625
# DONE with Epoch: 447, Loss EPOCH: 272415.40625
# DONE with Epoch: 448, Loss EPOCH: 273613.25
# DONE with Epoch: 449, Loss EPOCH: 380340.96875
# DONE with Epoch: 450, Loss EPOCH: 294021.65625
# DONE with Epoch: 451, Loss EPOCH: 223707.46875
# DONE with Epoch: 452, Loss EPOCH: 274914.4375
# DONE with Epoch: 453, Loss EPOCH: 309385.5
# DONE with Epoch: 454, Loss EPOCH: 234674.796875
# DONE with Epoch: 455, Loss EPOCH: 199236.78125
# DONE with Epoch: 456, Loss EPOCH: 255105.3125
# DONE with Epoch: 457, Loss EPOCH: 258413.375
# DONE with Epoch: 458, Loss EPOCH: 210704.546875
# DONE with Epoch: 459, Loss EPOCH: 201191.625
# DONE with Epoch: 460, Loss EPOCH: 202639.4375
# DONE with Epoch: 461, Loss EPOCH: 208846.5
# DONE with Epoch: 462, Loss EPOCH: 239266.0
# DONE with Epoch: 463, Loss EPOCH: 238508.46875
# DONE with Epoch: 464, Loss EPOCH: 216660.203125
# DONE with Epoch: 465, Loss EPOCH: 220668.84375
# DONE with Epoch: 466, Loss EPOCH: 231323.203125
# DONE with Epoch: 467, Loss EPOCH: 263007.25
# DONE with Epoch: 468, Loss EPOCH: 342416.375
# DONE with Epoch: 469, Loss EPOCH: 434472.75
# DONE with Epoch: 470, Loss EPOCH: 487399.0625
# DONE with Epoch: 471, Loss EPOCH: 406683.25
# DONE with Epoch: 472, Loss EPOCH: 281207.5625
# DONE with Epoch: 473, Loss EPOCH: 240099.34375
# DONE with Epoch: 474, Loss EPOCH: 283050.34375
# DONE with Epoch: 475, Loss EPOCH: 262470.65625
# DONE with Epoch: 476, Loss EPOCH: 226321.90625
# DONE with Epoch: 477, Loss EPOCH: 201434.234375
# DONE with Epoch: 478, Loss EPOCH: 222960.125
# DONE with Epoch: 479, Loss EPOCH: 262202.5
# DONE with Epoch: 480, Loss EPOCH: 224962.96875
# DONE with Epoch: 481, Loss EPOCH: 164792.859375
# DONE with Epoch: 482, Loss EPOCH: 163378.375
# DONE with Epoch: 483, Loss EPOCH: 186642.8125
# DONE with Epoch: 484, Loss EPOCH: 196701.53125
# DONE with Epoch: 485, Loss EPOCH: 203050.171875
# DONE with Epoch: 486, Loss EPOCH: 181718.546875
# DONE with Epoch: 487, Loss EPOCH: 163274.390625
# DONE with Epoch: 488, Loss EPOCH: 146865.625
# DONE with Epoch: 489, Loss EPOCH: 142331.5625
# DONE with Epoch: 490, Loss EPOCH: 154112.90625
# DONE with Epoch: 491, Loss EPOCH: 170732.125
# DONE with Epoch: 492, Loss EPOCH: 165375.75
# DONE with Epoch: 493, Loss EPOCH: 151528.1875
# DONE with Epoch: 494, Loss EPOCH: 150029.40625
# DONE with Epoch: 495, Loss EPOCH: 149202.03125
# DONE with Epoch: 496, Loss EPOCH: 139746.40625
# DONE with Epoch: 497, Loss EPOCH: 133505.25
# DONE with Epoch: 498, Loss EPOCH: 135142.8125
# DONE with Epoch: 499, Loss EPOCH: 146388.5625
# DONE with Epoch: 500, Loss EPOCH: 194756.9375
# DONE with Epoch: 501, Loss EPOCH: 306429.03125
# DONE with Epoch: 502, Loss EPOCH: 542681.875
# DONE with Epoch: 503, Loss EPOCH: 689554.9375
# DONE with Epoch: 504, Loss EPOCH: 659532.125
# DONE with Epoch: 505, Loss EPOCH: 317451.09375
# DONE with Epoch: 506, Loss EPOCH: 332443.9375
# DONE with Epoch: 507, Loss EPOCH: 457665.71875
# DONE with Epoch: 508, Loss EPOCH: 316004.28125
# DONE with Epoch: 509, Loss EPOCH: 231460.78125
# DONE with Epoch: 510, Loss EPOCH: 361242.125
# DONE with Epoch: 511, Loss EPOCH: 279604.65625
# DONE with Epoch: 512, Loss EPOCH: 177693.703125
# DONE with Epoch: 513, Loss EPOCH: 257776.4375
# DONE with Epoch: 514, Loss EPOCH: 241224.875
# DONE with Epoch: 515, Loss EPOCH: 192968.28125
# DONE with Epoch: 516, Loss EPOCH: 182192.390625
# DONE with Epoch: 517, Loss EPOCH: 194847.578125
# DONE with Epoch: 518, Loss EPOCH: 170775.828125
# DONE with Epoch: 519, Loss EPOCH: 179266.03125
# DONE with Epoch: 520, Loss EPOCH: 182038.328125
# DONE with Epoch: 521, Loss EPOCH: 135623.21875
# DONE with Epoch: 522, Loss EPOCH: 170145.0
# DONE with Epoch: 523, Loss EPOCH: 200771.359375
# DONE with Epoch: 524, Loss EPOCH: 150716.09375
# DONE with Epoch: 525, Loss EPOCH: 180316.796875
# DONE with Epoch: 526, Loss EPOCH: 152507.203125
# DONE with Epoch: 527, Loss EPOCH: 128770.375
# DONE with Epoch: 528, Loss EPOCH: 119355.28125
# DONE with Epoch: 529, Loss EPOCH: 125639.6484375
# DONE with Epoch: 530, Loss EPOCH: 114728.53125
# DONE with Epoch: 531, Loss EPOCH: 123218.0625
# DONE with Epoch: 532, Loss EPOCH: 131986.734375
# DONE with Epoch: 533, Loss EPOCH: 141297.5
# DONE with Epoch: 534, Loss EPOCH: 145644.390625
# DONE with Epoch: 535, Loss EPOCH: 159095.359375
# DONE with Epoch: 536, Loss EPOCH: 178541.046875
# DONE with Epoch: 537, Loss EPOCH: 161282.125
# DONE with Epoch: 538, Loss EPOCH: 155030.65625
# DONE with Epoch: 539, Loss EPOCH: 122063.953125
# DONE with Epoch: 540, Loss EPOCH: 126638.9375
# DONE with Epoch: 541, Loss EPOCH: 136030.421875
# DONE with Epoch: 542, Loss EPOCH: 152922.375
# DONE with Epoch: 543, Loss EPOCH: 130464.671875
# DONE with Epoch: 544, Loss EPOCH: 108623.1484375
# DONE with Epoch: 545, Loss EPOCH: 92911.234375
# DONE with Epoch: 546, Loss EPOCH: 97987.6015625
# DONE with Epoch: 547, Loss EPOCH: 99261.96875
# DONE with Epoch: 548, Loss EPOCH: 94235.53125
# DONE with Epoch: 549, Loss EPOCH: 86267.671875
# DONE with Epoch: 550, Loss EPOCH: 89857.1015625
# DONE with Epoch: 551, Loss EPOCH: 98633.5625
# DONE with Epoch: 552, Loss EPOCH: 108336.796875
# DONE with Epoch: 553, Loss EPOCH: 112959.9375
# DONE with Epoch: 554, Loss EPOCH: 118209.5859375
# DONE with Epoch: 555, Loss EPOCH: 132004.0
# DONE with Epoch: 556, Loss EPOCH: 151770.34375
# DONE with Epoch: 557, Loss EPOCH: 184948.34375
# DONE with Epoch: 558, Loss EPOCH: 220445.0625
# DONE with Epoch: 559, Loss EPOCH: 237930.09375
# DONE with Epoch: 560, Loss EPOCH: 222922.6875
# DONE with Epoch: 561, Loss EPOCH: 164183.921875
# DONE with Epoch: 562, Loss EPOCH: 96247.9765625
# DONE with Epoch: 563, Loss EPOCH: 70152.0703125
# DONE with Epoch: 564, Loss EPOCH: 96501.671875
# DONE with Epoch: 565, Loss EPOCH: 124038.265625
# DONE with Epoch: 566, Loss EPOCH: 115451.6328125
# DONE with Epoch: 567, Loss EPOCH: 88015.015625
# DONE with Epoch: 568, Loss EPOCH: 77948.5
# DONE with Epoch: 569, Loss EPOCH: 88377.8828125
# DONE with Epoch: 570, Loss EPOCH: 99383.4375
# DONE with Epoch: 571, Loss EPOCH: 89724.3828125
# DONE with Epoch: 572, Loss EPOCH: 74212.3125
# DONE with Epoch: 573, Loss EPOCH: 66841.1875
# DONE with Epoch: 574, Loss EPOCH: 70412.84375
# DONE with Epoch: 575, Loss EPOCH: 76266.3671875
# DONE with Epoch: 576, Loss EPOCH: 77827.125
# DONE with Epoch: 577, Loss EPOCH: 76786.3125
# DONE with Epoch: 578, Loss EPOCH: 72303.2421875
# DONE with Epoch: 579, Loss EPOCH: 68435.4921875
# DONE with Epoch: 580, Loss EPOCH: 67902.3984375
# DONE with Epoch: 581, Loss EPOCH: 74450.1484375
# DONE with Epoch: 582, Loss EPOCH: 93866.1015625
# DONE with Epoch: 583, Loss EPOCH: 134846.875
# DONE with Epoch: 584, Loss EPOCH: 215398.734375
# DONE with Epoch: 585, Loss EPOCH: 333311.46875
# DONE with Epoch: 586, Loss EPOCH: 434335.6875
# DONE with Epoch: 587, Loss EPOCH: 421566.40625
# DONE with Epoch: 588, Loss EPOCH: 238405.1875
# DONE with Epoch: 589, Loss EPOCH: 110000.1328125
# DONE with Epoch: 590, Loss EPOCH: 186808.46875
# DONE with Epoch: 591, Loss EPOCH: 233642.25
# DONE with Epoch: 592, Loss EPOCH: 129965.015625
# DONE with Epoch: 593, Loss EPOCH: 84306.2421875
# DONE with Epoch: 594, Loss EPOCH: 166232.75
# DONE with Epoch: 595, Loss EPOCH: 170441.265625
# DONE with Epoch: 596, Loss EPOCH: 89664.9609375
# DONE with Epoch: 597, Loss EPOCH: 76972.5546875
# DONE with Epoch: 598, Loss EPOCH: 122591.703125
# DONE with Epoch: 599, Loss EPOCH: 124777.0
# DONE with Epoch: 600, Loss EPOCH: 79986.390625
# DONE with Epoch: 601, Loss EPOCH: 60138.48046875
# DONE with Epoch: 602, Loss EPOCH: 90817.671875
# DONE with Epoch: 603, Loss EPOCH: 108099.03125
# DONE with Epoch: 604, Loss EPOCH: 80354.2578125
# DONE with Epoch: 605, Loss EPOCH: 59272.0
# DONE with Epoch: 606, Loss EPOCH: 60718.69921875
# DONE with Epoch: 607, Loss EPOCH: 75722.1875
# DONE with Epoch: 608, Loss EPOCH: 90840.9375
# DONE with Epoch: 609, Loss EPOCH: 86010.53125
# DONE with Epoch: 610, Loss EPOCH: 77373.6484375
# DONE with Epoch: 611, Loss EPOCH: 82112.8984375
# DONE with Epoch: 612, Loss EPOCH: 115832.46875
# DONE with Epoch: 613, Loss EPOCH: 177244.53125
# DONE with Epoch: 614, Loss EPOCH: 256796.140625
# DONE with Epoch: 615, Loss EPOCH: 334363.8125
# DONE with Epoch: 616, Loss EPOCH: 361651.5625
# DONE with Epoch: 617, Loss EPOCH: 275819.21875
# DONE with Epoch: 618, Loss EPOCH: 133701.875
# DONE with Epoch: 619, Loss EPOCH: 66190.765625
# DONE with Epoch: 620, Loss EPOCH: 134836.78125
# DONE with Epoch: 621, Loss EPOCH: 176971.75
# DONE with Epoch: 622, Loss EPOCH: 100660.3828125
# DONE with Epoch: 623, Loss EPOCH: 59908.20703125
# DONE with Epoch: 624, Loss EPOCH: 114462.875
# DONE with Epoch: 625, Loss EPOCH: 133115.921875
# DONE with Epoch: 626, Loss EPOCH: 75792.5078125
# DONE with Epoch: 627, Loss EPOCH: 52570.29296875
# DONE with Epoch: 628, Loss EPOCH: 90050.5
# DONE with Epoch: 629, Loss EPOCH: 98931.6015625
# DONE with Epoch: 630, Loss EPOCH: 70122.6953125
# DONE with Epoch: 631, Loss EPOCH: 53814.34765625
# DONE with Epoch: 632, Loss EPOCH: 64223.6015625
# DONE with Epoch: 633, Loss EPOCH: 78644.7421875
# DONE with Epoch: 634, Loss EPOCH: 78182.96875
# DONE with Epoch: 635, Loss EPOCH: 55255.3984375
# DONE with Epoch: 636, Loss EPOCH: 41336.76171875
# DONE with Epoch: 637, Loss EPOCH: 46066.46875
# DONE with Epoch: 638, Loss EPOCH: 54537.55859375
# DONE with Epoch: 639, Loss EPOCH: 61614.78515625
# DONE with Epoch: 640, Loss EPOCH: 64606.37109375
# DONE with Epoch: 641, Loss EPOCH: 67663.15625
# DONE with Epoch: 642, Loss EPOCH: 56922.5234375
# DONE with Epoch: 643, Loss EPOCH: 51060.52734375
# DONE with Epoch: 644, Loss EPOCH: 54517.6640625
# DONE with Epoch: 645, Loss EPOCH: 69240.328125
# DONE with Epoch: 646, Loss EPOCH: 95819.9609375
# DONE with Epoch: 647, Loss EPOCH: 126631.890625
# DONE with Epoch: 648, Loss EPOCH: 161553.875
# DONE with Epoch: 649, Loss EPOCH: 171463.21875
# DONE with Epoch: 650, Loss EPOCH: 129786.09375
# DONE with Epoch: 651, Loss EPOCH: 76115.4296875
# DONE with Epoch: 652, Loss EPOCH: 53261.60546875
# DONE with Epoch: 653, Loss EPOCH: 60614.30078125
# DONE with Epoch: 654, Loss EPOCH: 77330.046875
# DONE with Epoch: 655, Loss EPOCH: 78162.8359375
# DONE with Epoch: 656, Loss EPOCH: 61946.11328125
# DONE with Epoch: 657, Loss EPOCH: 52384.296875
# DONE with Epoch: 658, Loss EPOCH: 51047.3125
# DONE with Epoch: 659, Loss EPOCH: 51161.12890625
# DONE with Epoch: 660, Loss EPOCH: 54800.0078125
# DONE with Epoch: 661, Loss EPOCH: 53998.01171875
# DONE with Epoch: 662, Loss EPOCH: 44663.62890625
# DONE with Epoch: 663, Loss EPOCH: 37957.2421875
# DONE with Epoch: 664, Loss EPOCH: 39265.734375
# DONE with Epoch: 665, Loss EPOCH: 45225.6796875
# DONE with Epoch: 666, Loss EPOCH: 47633.61328125
# DONE with Epoch: 667, Loss EPOCH: 40116.73046875
# DONE with Epoch: 668, Loss EPOCH: 31470.484375
# DONE with Epoch: 669, Loss EPOCH: 31115.80859375
# DONE with Epoch: 670, Loss EPOCH: 36215.5703125
# DONE with Epoch: 671, Loss EPOCH: 36809.34765625
# DONE with Epoch: 672, Loss EPOCH: 34097.65234375
# DONE with Epoch: 673, Loss EPOCH: 36609.03515625
# DONE with Epoch: 674, Loss EPOCH: 42600.96875
# DONE with Epoch: 675, Loss EPOCH: 44088.5546875
# DONE with Epoch: 676, Loss EPOCH: 42540.3515625
# DONE with Epoch: 677, Loss EPOCH: 42815.6953125
# DONE with Epoch: 678, Loss EPOCH: 45990.4765625
# DONE with Epoch: 679, Loss EPOCH: 49951.1484375
# DONE with Epoch: 680, Loss EPOCH: 53763.1953125
# DONE with Epoch: 681, Loss EPOCH: 59366.0625
# DONE with Epoch: 682, Loss EPOCH: 70789.484375
# DONE with Epoch: 683, Loss EPOCH: 93736.1796875
# DONE with Epoch: 684, Loss EPOCH: 142278.625
# DONE with Epoch: 685, Loss EPOCH: 214190.84375
# DONE with Epoch: 686, Loss EPOCH: 315358.59375
# DONE with Epoch: 687, Loss EPOCH: 297456.9375
# DONE with Epoch: 688, Loss EPOCH: 219794.265625
# DONE with Epoch: 689, Loss EPOCH: 100216.71875
# DONE with Epoch: 690, Loss EPOCH: 81762.296875
# DONE with Epoch: 691, Loss EPOCH: 145582.203125
# DONE with Epoch: 692, Loss EPOCH: 149751.703125
# DONE with Epoch: 693, Loss EPOCH: 76820.9296875
# DONE with Epoch: 694, Loss EPOCH: 64260.80859375
# DONE with Epoch: 695, Loss EPOCH: 118498.8984375
# DONE with Epoch: 696, Loss EPOCH: 96757.765625
# DONE with Epoch: 697, Loss EPOCH: 51913.17578125
# DONE with Epoch: 698, Loss EPOCH: 61180.203125
# DONE with Epoch: 699, Loss EPOCH: 75552.578125
# DONE with Epoch: 700, Loss EPOCH: 69175.125
# DONE with Epoch: 701, Loss EPOCH: 60716.60546875
# DONE with Epoch: 702, Loss EPOCH: 56374.109375
# DONE with Epoch: 703, Loss EPOCH: 67308.8984375
# DONE with Epoch: 704, Loss EPOCH: 74672.4375
# DONE with Epoch: 705, Loss EPOCH: 68835.84375
# DONE with Epoch: 706, Loss EPOCH: 65854.71875
# DONE with Epoch: 707, Loss EPOCH: 65230.0625
# DONE with Epoch: 708, Loss EPOCH: 81612.78125
# DONE with Epoch: 709, Loss EPOCH: 106885.8671875
# DONE with Epoch: 710, Loss EPOCH: 107856.0625
# DONE with Epoch: 711, Loss EPOCH: 109312.59375
# DONE with Epoch: 712, Loss EPOCH: 118441.3671875
# DONE with Epoch: 713, Loss EPOCH: 110075.2109375
# DONE with Epoch: 714, Loss EPOCH: 82049.6484375
# DONE with Epoch: 715, Loss EPOCH: 51312.5234375
# DONE with Epoch: 716, Loss EPOCH: 35470.125
# DONE with Epoch: 717, Loss EPOCH: 36847.11328125
# DONE with Epoch: 718, Loss EPOCH: 55566.10546875
# DONE with Epoch: 719, Loss EPOCH: 67987.25
# DONE with Epoch: 720, Loss EPOCH: 55658.75
# DONE with Epoch: 721, Loss EPOCH: 35136.8359375
# DONE with Epoch: 722, Loss EPOCH: 28224.01953125
# DONE with Epoch: 723, Loss EPOCH: 31853.732421875
# DONE with Epoch: 724, Loss EPOCH: 36771.59765625
# DONE with Epoch: 725, Loss EPOCH: 41835.0625
# DONE with Epoch: 726, Loss EPOCH: 43811.77734375
# DONE with Epoch: 727, Loss EPOCH: 36974.8828125
# DONE with Epoch: 728, Loss EPOCH: 30143.6015625
# DONE with Epoch: 729, Loss EPOCH: 28692.080078125
# DONE with Epoch: 730, Loss EPOCH: 29768.72265625
# DONE with Epoch: 731, Loss EPOCH: 30431.408203125
# DONE with Epoch: 732, Loss EPOCH: 31120.17578125
# DONE with Epoch: 733, Loss EPOCH: 32551.1796875
# DONE with Epoch: 734, Loss EPOCH: 32372.74609375
# DONE with Epoch: 735, Loss EPOCH: 31717.40234375
# DONE with Epoch: 736, Loss EPOCH: 31280.7109375
# DONE with Epoch: 737, Loss EPOCH: 31864.1484375
# DONE with Epoch: 738, Loss EPOCH: 33987.1015625
# DONE with Epoch: 739, Loss EPOCH: 37156.3125
# DONE with Epoch: 740, Loss EPOCH: 41457.15234375
# DONE with Epoch: 741, Loss EPOCH: 47343.6953125
# DONE with Epoch: 742, Loss EPOCH: 55252.171875
# DONE with Epoch: 743, Loss EPOCH: 62730.6796875
# DONE with Epoch: 744, Loss EPOCH: 70780.640625
# DONE with Epoch: 745, Loss EPOCH: 77138.4375
# DONE with Epoch: 746, Loss EPOCH: 82729.03125
# DONE with Epoch: 747, Loss EPOCH: 83891.84375
# DONE with Epoch: 748, Loss EPOCH: 81291.75
# DONE with Epoch: 749, Loss EPOCH: 74159.3671875
# DONE with Epoch: 750, Loss EPOCH: 64619.6171875
# DONE with Epoch: 751, Loss EPOCH: 55890.54296875
# DONE with Epoch: 752, Loss EPOCH: 45928.10546875
# DONE with Epoch: 753, Loss EPOCH: 40581.12109375
# DONE with Epoch: 754, Loss EPOCH: 37957.94921875
# DONE with Epoch: 755, Loss EPOCH: 37364.7109375
# DONE with Epoch: 756, Loss EPOCH: 36545.66015625
# DONE with Epoch: 757, Loss EPOCH: 35993.06640625
# DONE with Epoch: 758, Loss EPOCH: 36451.40625
# DONE with Epoch: 759, Loss EPOCH: 36149.91796875
# DONE with Epoch: 760, Loss EPOCH: 34456.484375
# DONE with Epoch: 761, Loss EPOCH: 30021.0390625
# DONE with Epoch: 762, Loss EPOCH: 26050.7890625
# DONE with Epoch: 763, Loss EPOCH: 25059.150390625
# DONE with Epoch: 764, Loss EPOCH: 27526.849609375
# DONE with Epoch: 765, Loss EPOCH: 31207.650390625
# DONE with Epoch: 766, Loss EPOCH: 33492.79296875
# DONE with Epoch: 767, Loss EPOCH: 33523.69921875
# DONE with Epoch: 768, Loss EPOCH: 31086.154296875
# DONE with Epoch: 769, Loss EPOCH: 27910.953125
# DONE with Epoch: 770, Loss EPOCH: 24994.27734375
# DONE with Epoch: 771, Loss EPOCH: 23550.896484375
# DONE with Epoch: 772, Loss EPOCH: 23448.232421875
# DONE with Epoch: 773, Loss EPOCH: 24675.640625
# DONE with Epoch: 774, Loss EPOCH: 27371.990234375
# DONE with Epoch: 775, Loss EPOCH: 31739.134765625
# DONE with Epoch: 776, Loss EPOCH: 38799.53515625
# DONE with Epoch: 777, Loss EPOCH: 49635.3125
# DONE with Epoch: 778, Loss EPOCH: 68591.015625
# DONE with Epoch: 779, Loss EPOCH: 98349.1328125
# DONE with Epoch: 780, Loss EPOCH: 148241.265625
# DONE with Epoch: 781, Loss EPOCH: 213524.328125
# DONE with Epoch: 782, Loss EPOCH: 283170.90625
# DONE with Epoch: 783, Loss EPOCH: 292172.6875
# DONE with Epoch: 784, Loss EPOCH: 204403.65625
# DONE with Epoch: 785, Loss EPOCH: 84018.4453125
# DONE with Epoch: 786, Loss EPOCH: 56963.8984375
# DONE with Epoch: 787, Loss EPOCH: 108714.546875
# DONE with Epoch: 788, Loss EPOCH: 128763.46875
# DONE with Epoch: 789, Loss EPOCH: 82642.0625
# DONE with Epoch: 790, Loss EPOCH: 43314.01171875
# DONE with Epoch: 791, Loss EPOCH: 72283.046875
# DONE with Epoch: 792, Loss EPOCH: 102035.015625
# DONE with Epoch: 793, Loss EPOCH: 65436.24609375
# DONE with Epoch: 794, Loss EPOCH: 32285.345703125
# DONE with Epoch: 795, Loss EPOCH: 44127.58984375
# DONE with Epoch: 796, Loss EPOCH: 60275.92578125
# DONE with Epoch: 797, Loss EPOCH: 70049.09375
# DONE with Epoch: 798, Loss EPOCH: 62782.46875
# DONE with Epoch: 799, Loss EPOCH: 50255.25
# DONE with Epoch: 800, Loss EPOCH: 33933.1640625
# DONE with Epoch: 801, Loss EPOCH: 31039.435546875
# DONE with Epoch: 802, Loss EPOCH: 41811.828125
# DONE with Epoch: 803, Loss EPOCH: 60720.0078125
# DONE with Epoch: 804, Loss EPOCH: 76296.9375
# DONE with Epoch: 805, Loss EPOCH: 100025.6953125
# DONE with Epoch: 806, Loss EPOCH: 124556.6640625
# DONE with Epoch: 807, Loss EPOCH: 137424.984375
# DONE with Epoch: 808, Loss EPOCH: 120867.28125
# DONE with Epoch: 809, Loss EPOCH: 80813.734375
# DONE with Epoch: 810, Loss EPOCH: 41037.79296875
# DONE with Epoch: 811, Loss EPOCH: 34209.390625
# DONE with Epoch: 812, Loss EPOCH: 58650.5390625
# DONE with Epoch: 813, Loss EPOCH: 79822.46875
# DONE with Epoch: 814, Loss EPOCH: 71864.6796875
# DONE with Epoch: 815, Loss EPOCH: 45090.6015625
# DONE with Epoch: 816, Loss EPOCH: 25682.46484375
# DONE with Epoch: 817, Loss EPOCH: 28832.19140625
# DONE with Epoch: 818, Loss EPOCH: 39698.390625
# DONE with Epoch: 819, Loss EPOCH: 42039.5625
# DONE with Epoch: 820, Loss EPOCH: 34361.015625
# DONE with Epoch: 821, Loss EPOCH: 28819.296875
# DONE with Epoch: 822, Loss EPOCH: 28793.130859375
# DONE with Epoch: 823, Loss EPOCH: 31703.28515625
# DONE with Epoch: 824, Loss EPOCH: 34726.9296875
# DONE with Epoch: 825, Loss EPOCH: 34014.0546875
# DONE with Epoch: 826, Loss EPOCH: 30128.875
# DONE with Epoch: 827, Loss EPOCH: 23068.96875
# DONE with Epoch: 828, Loss EPOCH: 19867.58984375
# DONE with Epoch: 829, Loss EPOCH: 22363.814453125
# DONE with Epoch: 830, Loss EPOCH: 26989.900390625
# DONE with Epoch: 831, Loss EPOCH: 28494.435546875
# DONE with Epoch: 832, Loss EPOCH: 27069.318359375
# DONE with Epoch: 833, Loss EPOCH: 25283.541015625
# DONE with Epoch: 834, Loss EPOCH: 25217.14453125
# DONE with Epoch: 835, Loss EPOCH: 27717.1015625
# DONE with Epoch: 836, Loss EPOCH: 33354.56640625
# DONE with Epoch: 837, Loss EPOCH: 43118.79296875
# DONE with Epoch: 838, Loss EPOCH: 60296.10546875
# DONE with Epoch: 839, Loss EPOCH: 85015.3046875
# DONE with Epoch: 840, Loss EPOCH: 121347.90625
# DONE with Epoch: 841, Loss EPOCH: 162378.6875
# DONE with Epoch: 842, Loss EPOCH: 202587.140625
# DONE with Epoch: 843, Loss EPOCH: 208439.34375
# DONE with Epoch: 844, Loss EPOCH: 165697.5
# DONE with Epoch: 845, Loss EPOCH: 86090.7890625
# DONE with Epoch: 846, Loss EPOCH: 41155.66796875
# DONE with Epoch: 847, Loss EPOCH: 61730.8203125
# DONE with Epoch: 848, Loss EPOCH: 92840.6953125
# DONE with Epoch: 849, Loss EPOCH: 77968.46875
# DONE with Epoch: 850, Loss EPOCH: 36647.44921875
# DONE with Epoch: 851, Loss EPOCH: 33907.3359375
# DONE with Epoch: 852, Loss EPOCH: 64557.4296875
# DONE with Epoch: 853, Loss EPOCH: 71285.203125
# DONE with Epoch: 854, Loss EPOCH: 44953.078125
# DONE with Epoch: 855, Loss EPOCH: 20342.85546875
# DONE with Epoch: 856, Loss EPOCH: 27766.76953125
# DONE with Epoch: 857, Loss EPOCH: 49279.3671875
# DONE with Epoch: 858, Loss EPOCH: 51487.7421875
# DONE with Epoch: 859, Loss EPOCH: 35951.0625
# DONE with Epoch: 860, Loss EPOCH: 20030.28125
# DONE with Epoch: 861, Loss EPOCH: 19283.91796875
# DONE with Epoch: 862, Loss EPOCH: 29697.259765625
# DONE with Epoch: 863, Loss EPOCH: 39183.03515625
# DONE with Epoch: 864, Loss EPOCH: 41250.04296875
# DONE with Epoch: 865, Loss EPOCH: 34754.87109375
# DONE with Epoch: 866, Loss EPOCH: 30174.95703125
# DONE with Epoch: 867, Loss EPOCH: 37039.5859375
# DONE with Epoch: 868, Loss EPOCH: 63142.9453125
# DONE with Epoch: 869, Loss EPOCH: 117485.578125
# DONE with Epoch: 870, Loss EPOCH: 199381.6875
# DONE with Epoch: 871, Loss EPOCH: 305312.15625
# DONE with Epoch: 872, Loss EPOCH: 343434.6875
# DONE with Epoch: 873, Loss EPOCH: 244717.515625
# DONE with Epoch: 874, Loss EPOCH: 113361.890625
# DONE with Epoch: 875, Loss EPOCH: 75524.796875
# DONE with Epoch: 876, Loss EPOCH: 168582.53125
# DONE with Epoch: 877, Loss EPOCH: 160965.28125
# DONE with Epoch: 878, Loss EPOCH: 59495.06640625
# DONE with Epoch: 879, Loss EPOCH: 78282.7734375
# DONE with Epoch: 880, Loss EPOCH: 113587.15625
# DONE with Epoch: 881, Loss EPOCH: 96739.59375
# DONE with Epoch: 882, Loss EPOCH: 69696.1796875
# DONE with Epoch: 883, Loss EPOCH: 59175.9921875
# DONE with Epoch: 884, Loss EPOCH: 56111.28125
# DONE with Epoch: 885, Loss EPOCH: 63480.4609375
# DONE with Epoch: 886, Loss EPOCH: 55137.0234375
# DONE with Epoch: 887, Loss EPOCH: 50779.51953125
# DONE with Epoch: 888, Loss EPOCH: 41991.546875
# DONE with Epoch: 889, Loss EPOCH: 38273.2265625
# DONE with Epoch: 890, Loss EPOCH: 56732.84765625
# DONE with Epoch: 891, Loss EPOCH: 69410.609375
# DONE with Epoch: 892, Loss EPOCH: 79518.59375
# DONE with Epoch: 893, Loss EPOCH: 170998.875
# DONE with Epoch: 894, Loss EPOCH: 404027.34375
# DONE with Epoch: 895, Loss EPOCH: 781266.75
# DONE with Epoch: 896, Loss EPOCH: 1121581.0
# DONE with Epoch: 897, Loss EPOCH: 733469.625
# DONE with Epoch: 898, Loss EPOCH: 171343.921875
# DONE with Epoch: 899, Loss EPOCH: 436852.5625
# DONE with Epoch: 900, Loss EPOCH: 396147.21875
# DONE with Epoch: 901, Loss EPOCH: 239041.0625
# DONE with Epoch: 902, Loss EPOCH: 327097.53125
# DONE with Epoch: 903, Loss EPOCH: 256942.59375
# DONE with Epoch: 904, Loss EPOCH: 193812.359375
# DONE with Epoch: 905, Loss EPOCH: 203030.21875
# DONE with Epoch: 906, Loss EPOCH: 188382.8125
# DONE with Epoch: 907, Loss EPOCH: 148769.25
# DONE with Epoch: 908, Loss EPOCH: 143765.34375
# DONE with Epoch: 909, Loss EPOCH: 134954.296875
# DONE with Epoch: 910, Loss EPOCH: 294594.59375
# DONE with Epoch: 911, Loss EPOCH: 956071.3125
# DONE with Epoch: 912, Loss EPOCH: 2778525.0
# DONE with Epoch: 913, Loss EPOCH: 1582663.5
# DONE with Epoch: 914, Loss EPOCH: 1092795.75
# DONE with Epoch: 915, Loss EPOCH: 1317292.375
# DONE with Epoch: 916, Loss EPOCH: 1616727.25
# DONE with Epoch: 917, Loss EPOCH: 2614517.0
# DONE with Epoch: 918, Loss EPOCH: 1654805.625
# DONE with Epoch: 919, Loss EPOCH: 1080378.25
# DONE with Epoch: 920, Loss EPOCH: 1459088.75
# DONE with Epoch: 921, Loss EPOCH: 1594102.25
# DONE with Epoch: 922, Loss EPOCH: 1735093.75
# DONE with Epoch: 923, Loss EPOCH: 2069777.875
# DONE with Epoch: 924, Loss EPOCH: 3741961.75
# DONE with Epoch: 925, Loss EPOCH: 4615626.0
# DONE with Epoch: 926, Loss EPOCH: 3055281.25
# DONE with Epoch: 927, Loss EPOCH: 3031059.0
# DONE with Epoch: 928, Loss EPOCH: 2434306.0
# DONE with Epoch: 929, Loss EPOCH: 2092695.0
# DONE with Epoch: 930, Loss EPOCH: 2012832.5
# DONE with Epoch: 931, Loss EPOCH: 2878048.75
# DONE with Epoch: 932, Loss EPOCH: 5943929.0
# DONE with Epoch: 933, Loss EPOCH: 3376934.75
# DONE with Epoch: 934, Loss EPOCH: 4404239.5
# DONE with Epoch: 935, Loss EPOCH: 3087431.5
# DONE with Epoch: 936, Loss EPOCH: 4758116.0
# DONE with Epoch: 937, Loss EPOCH: 5812484.5
# DONE with Epoch: 938, Loss EPOCH: 4261412.0
# DONE with Epoch: 939, Loss EPOCH: 3246340.5
# DONE with Epoch: 940, Loss EPOCH: 3576634.75
# DONE with Epoch: 941, Loss EPOCH: 2512275.0
# DONE with Epoch: 942, Loss EPOCH: 2374220.25
# DONE with Epoch: 943, Loss EPOCH: 2053653.75
# DONE with Epoch: 944, Loss EPOCH: 2343731.5
# DONE with Epoch: 945, Loss EPOCH: 3346717.5
# DONE with Epoch: 946, Loss EPOCH: 4475230.5
# DONE with Epoch: 947, Loss EPOCH: 6057382.5
# DONE with Epoch: 948, Loss EPOCH: 3635825.25
# DONE with Epoch: 949, Loss EPOCH: 4805684.0
# DONE with Epoch: 950, Loss EPOCH: 3461193.75
# DONE with Epoch: 951, Loss EPOCH: 3284232.5
# DONE with Epoch: 952, Loss EPOCH: 3110935.75
# DONE with Epoch: 953, Loss EPOCH: 2206727.75
# DONE with Epoch: 954, Loss EPOCH: 2005071.25
# DONE with Epoch: 955, Loss EPOCH: 2236139.25
# DONE with Epoch: 956, Loss EPOCH: 3978432.0
# DONE with Epoch: 957, Loss EPOCH: 5449328.0
# DONE with Epoch: 958, Loss EPOCH: 3833559.0
# DONE with Epoch: 959, Loss EPOCH: 3288315.75
# DONE with Epoch: 960, Loss EPOCH: 2426054.0
# DONE with Epoch: 961, Loss EPOCH: 2577446.25
# DONE with Epoch: 962, Loss EPOCH: 2128439.25
# DONE with Epoch: 963, Loss EPOCH: 2997795.75
# DONE with Epoch: 964, Loss EPOCH: 3850274.25
# DONE with Epoch: 965, Loss EPOCH: 3451637.75
# DONE with Epoch: 966, Loss EPOCH: 1854397.0
# DONE with Epoch: 967, Loss EPOCH: 1966103.75
# DONE with Epoch: 968, Loss EPOCH: 2019585.25
# DONE with Epoch: 969, Loss EPOCH: 1861121.875
# DONE with Epoch: 970, Loss EPOCH: 1487455.125
# DONE with Epoch: 971, Loss EPOCH: 1264417.625
# DONE with Epoch: 972, Loss EPOCH: 1006797.5625
# DONE with Epoch: 973, Loss EPOCH: 903239.375
# DONE with Epoch: 974, Loss EPOCH: 767694.9375
# DONE with Epoch: 975, Loss EPOCH: 860566.5625
# DONE with Epoch: 976, Loss EPOCH: 1177854.25
# DONE with Epoch: 977, Loss EPOCH: 1347933.5
# DONE with Epoch: 978, Loss EPOCH: 1600307.125
# DONE with Epoch: 979, Loss EPOCH: 1180422.375
# DONE with Epoch: 980, Loss EPOCH: 875338.0
# DONE with Epoch: 981, Loss EPOCH: 868117.8125
# DONE with Epoch: 982, Loss EPOCH: 842259.875
# DONE with Epoch: 983, Loss EPOCH: 575670.625
# DONE with Epoch: 984, Loss EPOCH: 582666.375
# DONE with Epoch: 985, Loss EPOCH: 498530.15625
# DONE with Epoch: 986, Loss EPOCH: 456166.875
# DONE with Epoch: 987, Loss EPOCH: 521676.90625
# DONE with Epoch: 988, Loss EPOCH: 510077.6875
# DONE with Epoch: 989, Loss EPOCH: 426938.5
# DONE with Epoch: 990, Loss EPOCH: 317787.84375
# DONE with Epoch: 991, Loss EPOCH: 271276.71875
# DONE with Epoch: 992, Loss EPOCH: 306428.34375
# DONE with Epoch: 993, Loss EPOCH: 302746.125
# DONE with Epoch: 994, Loss EPOCH: 294731.25
# DONE with Epoch: 995, Loss EPOCH: 280607.65625
# DONE with Epoch: 996, Loss EPOCH: 289734.4375
# DONE with Epoch: 997, Loss EPOCH: 245670.75
# DONE with Epoch: 998, Loss EPOCH: 198821.328125
# DONE with Epoch: 999, Loss EPOCH: 187999.65625
# DONE with Epoch: 1000, Loss EPOCH: 217058.84375
# DONE with Epoch: 1001, Loss EPOCH: 150963.6875
# DONE with Epoch: 1002, Loss EPOCH: 46455.51953125
# DONE with Epoch: 1003, Loss EPOCH: 32927.46484375
# DONE with Epoch: 1004, Loss EPOCH: 29751.447265625
# DONE with Epoch: 1005, Loss EPOCH: 27242.087890625
# DONE with Epoch: 1006, Loss EPOCH: 25814.91015625
# DONE with Epoch: 1007, Loss EPOCH: 23992.333984375
# DONE with Epoch: 1008, Loss EPOCH: 21799.150390625
# DONE with Epoch: 1009, Loss EPOCH: 19456.197265625
# DONE with Epoch: 1010, Loss EPOCH: 16983.958984375
# DONE with Epoch: 1011, Loss EPOCH: 15084.1103515625
# DONE with Epoch: 1012, Loss EPOCH: 12986.0234375
# DONE with Epoch: 1013, Loss EPOCH: 11134.6318359375
# DONE with Epoch: 1014, Loss EPOCH: 9706.330078125
# DONE with Epoch: 1015, Loss EPOCH: 8694.0654296875
# DONE with Epoch: 1016, Loss EPOCH: 7720.82177734375
# DONE with Epoch: 1017, Loss EPOCH: 6920.029296875
# DONE with Epoch: 1018, Loss EPOCH: 6279.2431640625
# DONE with Epoch: 1019, Loss EPOCH: 5628.53125
# DONE with Epoch: 1020, Loss EPOCH: 5123.7041015625
# DONE with Epoch: 1021, Loss EPOCH: 4691.7568359375
# DONE with Epoch: 1022, Loss EPOCH: 4306.9931640625
# DONE with Epoch: 1023, Loss EPOCH: 3911.171630859375
# DONE with Epoch: 1024, Loss EPOCH: 3487.00830078125
# DONE with Epoch: 1025, Loss EPOCH: 3138.35498046875
# DONE with Epoch: 1026, Loss EPOCH: 2839.7890625
# DONE with Epoch: 1027, Loss EPOCH: 2564.9775390625
# DONE with Epoch: 1028, Loss EPOCH: 2263.70556640625
# DONE with Epoch: 1029, Loss EPOCH: 1992.270751953125
# DONE with Epoch: 1030, Loss EPOCH: 1793.27294921875
# DONE with Epoch: 1031, Loss EPOCH: 1646.2777099609375
# DONE with Epoch: 1032, Loss EPOCH: 1543.11474609375
# DONE with Epoch: 1033, Loss EPOCH: 1416.7503662109375
# DONE with Epoch: 1034, Loss EPOCH: 1318.436279296875
# DONE with Epoch: 1035, Loss EPOCH: 1238.045654296875
# DONE with Epoch: 1036, Loss EPOCH: 1168.762451171875
# DONE with Epoch: 1037, Loss EPOCH: 1112.9481201171875
# ...
# DONE with Epoch: 1548, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1549, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1550, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1551, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1552, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1553, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1554, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1555, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1556, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1557, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1558, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1559, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1560, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1561, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1562, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1563, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1564, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1565, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1566, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1567, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1568, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1569, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1570, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1571, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1572, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1573, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1574, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1575, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1576, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1577, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1578, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1579, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1580, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1581, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1582, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1583, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1584, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1585, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1586, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1587, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1588, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1589, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1590, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1591, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1592, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1593, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1594, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1595, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1596, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1597, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1598, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1599, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1600, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1601, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1602, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1603, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1604, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1605, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1606, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1607, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1608, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1609, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1610, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1611, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1612, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1613, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1614, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1615, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1616, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1617, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1618, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1619, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1620, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1621, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1622, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1623, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1624, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1625, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1626, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1627, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1628, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1629, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1630, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1631, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1632, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1633, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1634, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1635, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1636, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1637, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1638, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1639, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1640, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1641, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1642, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1643, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1644, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1645, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1646, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1647, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1648, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1649, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1650, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1651, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1652, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1653, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1654, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1655, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1656, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1657, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1658, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1659, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1660, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1661, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1662, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1663, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1664, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1665, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1666, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1667, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1668, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1669, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1670, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1671, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1672, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1673, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1674, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1675, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1676, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1677, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1678, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1679, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1680, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1681, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1682, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1683, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1684, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1685, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1686, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1687, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1688, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1689, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1690, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1691, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1692, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1693, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1694, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1695, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1696, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1697, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1698, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1699, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1700, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1701, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1702, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1703, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1704, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1705, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1706, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1707, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1708, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1709, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1710, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1711, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1712, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1713, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1714, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1715, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1716, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1717, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1718, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1719, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1720, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1721, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1722, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1723, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1724, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1725, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1726, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1727, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1728, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1729, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1730, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1731, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1732, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1733, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1734, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1735, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1736, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1737, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1738, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1739, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1740, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1741, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1742, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1743, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1744, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1745, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1746, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1747, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1748, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1749, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1750, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1751, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1752, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1753, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1754, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1755, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1756, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1757, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1758, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1759, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1760, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1761, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1762, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1763, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1764, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1765, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1766, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1767, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1768, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1769, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1770, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1771, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1772, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1773, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1774, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1775, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1776, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1777, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1778, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1779, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1780, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1781, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1782, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1783, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1784, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1785, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1786, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1787, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1788, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1789, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1790, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1791, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1792, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1793, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1794, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1795, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1796, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1797, Loss EPOCH: 0.6474714279174805
# DONE with Epoch: 1798, Loss EPOCH: 0.6474714279174805
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-1d8ab192c9a5> in <module>
#     121
#     122     # Backward pass and optimization using L-BFGS
# --> 123     loss = optimizer.step(closure)
#     124     loss_epoch += loss.item()
#     125
#
# /usr/lib/python3/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     138                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139                 with torch.autograd.profiler.record_function(profile_name):
# --> 140                     out = func(*args, **kwargs)
#     141                     obj._optimizer_step_code()
#     142                     return out
#
# /usr/lib/python3/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/lib/python3/dist-packages/torch/optim/lbfgs.py in step(self, closure)
#     424                         return self._directional_evaluate(closure, x, t, d)
#     425
# --> 426                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#     427                         obj_func, x_init, t, d, loss, flat_grad, gtd)
#     428                 self._add_grad(t, d)
#
# /usr/lib/python3/dist-packages/torch/optim/lbfgs.py in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#     146
#     147         # Evaluate new point
# --> 148         f_new, g_new = obj_func(x, t, d)
#     149         ls_func_evals += 1
#     150         gtd_new = g_new.dot(d)
#
# /usr/lib/python3/dist-packages/torch/optim/lbfgs.py in obj_func(x, t, d)
#     422
#     423                     def obj_func(x, t, d):
# --> 424                         return self._directional_evaluate(closure, x, t, d)
#     425
#     426                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#
# /usr/lib/python3/dist-packages/torch/optim/lbfgs.py in _directional_evaluate(self, closure, x, t, d)
#     276     def _directional_evaluate(self, closure, x, t, d):
#     277         self._add_grad(t, d)
# --> 278         loss = float(closure())
#     279         flat_grad = self._gather_flat_grad()
#     280         self._set_param(x)
#
# KeyboardInterrupt:

# %%
temp_at_boundary = temp_net(boundary_data)

# %%
torch.save(temp_net, 'temp_net_trained_all_positive')

# %%
#temp_net = torch.load('temp_net_trained_all_positive')
# temp_net
#temp_net = temp_net.module

# %%
interior_data[:, 3], interior_data[:, 4]
# Out:
# (tensor([-0.3793, -0.3793, -0.3793,  ..., -0.3793, -0.3793, -0.3793],
#         device='cuda:0', grad_fn=<SelectBackward0>),
#  tensor([-1., -1., -1.,  ..., -1., -1., -1.], device='cuda:0',
#         grad_fn=<SelectBackward0>))

# %%
for i, sample_data in enumerate(train_loader, 0):
    boundary_data = sample_data['boundary'][0].to(device)
    interior_data = sample_data['interior'][0].to(device)
    sample_name = sample_data['sample'][0]

    # Unnormalize conditions
    speed = unnormalize_tensor(interior_data[:, 3], global_speed_min, global_speed_max)
    power = unnormalize_tensor(interior_data[:, 4], global_power_min, global_power_max)

    # Unnormalize coordinates
    interior_coords_unnorm = unnormalize_coordinates(interior_data[:, :3], global_x_min, 
                                                     global_x_max, global_y_min, 
                                                     global_y_max, global_z_min, global_z_max)

    print(f"Processing sample: {sample_name}")

    # Set the coordinates to require gradient computation
    boundary_data.requires_grad = True
    interior_data.requires_grad = True

    # Compute heat source for the interior coordinates
    Q_values_interior = heat_source(interior_coords_unnorm / 1000, power, spot_radius, eta)  
    break
# Out:
# Processing sample: f

# %%
total_loss = 0.0

#temp_net = temp_net.cpu().module
# Temperature Boundary Computations
temp_at_boundary = temp_net(boundary_data.cpu())

# Compute temperature gradients at the boundary
temp_gradients_boundary = torch.autograd.grad(
    temp_at_boundary.sum(), boundary_data,
    create_graph=True, retain_graph=True
)[0][:, :3]

# Compute the adiabatic residual at the boundary
adiabatic_residual_boundary = torch.mean(temp_gradients_boundary ** 2)
total_loss += adiabatic_residual_boundary

# Compute temperature residual at the boundary
temp_residual_boundary = temp_at_boundary - T_amb
temp_residual_boundary_mean = torch.mean(temp_residual_boundary ** 2)
total_loss += temp_residual_boundary_mean

# Temperature Interior Computations
temp_at_interior = temp_net(interior_data.cpu())

# Compute temperature gradients at the interior
temp_gradients_interior = torch.autograd.grad(
    temp_at_interior.sum(), interior_data,
    create_graph=True, retain_graph=True
)[0]

# Compute second partial derivatives (Laplacian components) for temperature at the interior
temp_gradients_interior_second = torch.autograd.grad(
    temp_gradients_interior.sum(), interior_data,
    create_graph=True, retain_graph=True
)[0][:, :3]

# Compute the Laplacian of temperature at the interior
temp_laplacian_interior = temp_gradients_interior_second.sum(dim=1)

# Compute the heat equation residual
heat_equation_residual = (
    rho * Cp * temp_gradients_interior[:, 0] * speed.flatten()
    + kappa * temp_laplacian_interior + Q_values_interior
)

# Compute the mean square of the heat equation residual
heat_equation_residual_mean = torch.mean(heat_equation_residual ** 2)

# Add heat equation residual to the total loss
total_loss += heat_equation_residual_mean

# Add Penalty for Negative Temperatures
negative_temp_penalty = torch.nn.ReLU()(-temp_at_interior)
negative_temp_penalty_mean = torch.mean(negative_temp_penalty ** 2)

# Add negative temperature penalty to the total loss
total_loss += negative_temp_penalty_mean
# Print each component of the total loss for debugging and analysis
print("Component-wise Loss Contributions:")
print(f"Adiabatic Residual at Boundary: {adiabatic_residual_boundary.item():.6f}")
print(f"Temperature Residual at Boundary: {temp_residual_boundary_mean.item():.6f}")
print(f"Heat Equation Residual: {heat_equation_residual_mean.item():.6f}")
print(f"Negative Temperature Penalty: {negative_temp_penalty_mean.item():.6f}")
print(f"Total Loss: {total_loss.item():.6f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-39-6ad2eb3bf9bc> in <module>
#       3 #temp_net = temp_net.cpu().module
#       4 # Temperature Boundary Computations
# ----> 5 temp_at_boundary = temp_net(boundary_data.cpu())
#       6
#       7 # Compute temperature gradients at the boundary
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-20-8cac49ba8886> in forward(self, x)
#      16     def forward(self, x):
#      17         # First layer followed by activation
# ---> 18         x1 = self.layer1(x)
#      19         x1_act = torch.tanh(x1)
#      20
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/lib/python3/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat1 in method wrapper_addmm)

# %%
inner = temp_gradients_interior[:, 0] * speed.flatten()
inner.shape, inner.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-1a602079bb81> in <module>
# ----> 1 inner = temp_gradients_interior[:, 0] * speed.flatten()
#       2 inner.shape, inner.max()
#
# NameError: name 'temp_gradients_interior' is not defined

# %%
temp_gradients_interior[:, 0].shape

# %%
device = 'cpu'

# %%
boundary_data = sample_data['boundary'][0].to(device)
interior_data = sample_data['interior'][0].to(device)
sample_name = sample_data['sample'][0]

# Unnormalize conditions
speed = unnormalize_tensor(interior_data[:, 3], global_speed_min, global_speed_max)
power = unnormalize_tensor(interior_data[:, 4], global_power_min, global_power_max)

# Unnormalize coordinates
interior_coords_unnorm = unnormalize_coordinates(interior_data[:, :3], global_x_min, 
                                                 global_x_max, global_y_min, 
                                                 global_y_max, global_z_min, global_z_max)

#print(f"Processing sample: {sample_name}")

# Set the coordinates to require gradient computation
boundary_data.requires_grad = True
interior_data.requires_grad = True

# Compute heat source for the interior coordinates
Q_values_interior = heat_source(interior_coords_unnorm / 1000, power, spot_radius, eta)     

temp = temp_net(interior_data)
temp.max(), speed, power, Q_values_interior.max()

# %%
temp.mean()

# %%
# %matplotlib

# %%
# Create a 3D scatter plot for temperature
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x, y, z = interior_data[:, 0].cpu().detach().numpy(), interior_data[:, 1].cpu().detach().numpy(), interior_data[:, 2].cpu().detach().numpy()

scatter = ax.scatter(x, y, z, c=Q_values_interior.cpu().detach().numpy(), cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Q')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Source')

plt.show()

# %%
# Create a 3D scatter plot for temperature
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x, y, z = interior_data[:, 0].cpu().detach().numpy(), interior_data[:, 1].cpu().detach().numpy(), interior_data[:, 2].cpu().detach().numpy()

scatter = ax.scatter(x, y, z, c=temp.cpu().detach().numpy(), cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Temperature')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Temperature Field')

plt.show()

# %%
# Find the maximum Y value
y_max = np.max(y)

# Create a mask for the points that are on the plane y = y_max
mask_y_max = (y == y_max)

# Filter the x, y, z coordinates and the adv values
x_filtered = x[mask_y_max]
y_filtered = y[mask_y_max]
z_filtered = z[mask_y_max]

adv = rho * Cp * temp_gradients_interior[:, 0].cpu() * speed.flatten().cpu()
adv_filtered = adv.cpu().detach().numpy()[mask_y_max]

# Create a 3D scatter plot for temperature
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Only plot the points that lie on the plane y = y_max
scatter = ax.scatter(x_filtered, y_filtered, z_filtered, c=adv_filtered, cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Q')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Advection term on the plane y = y_max')

plt.show()

print("Maximum value of advection term:", np.max(adv_filtered))

# %%
# Create a 3D scatter plot for temperature
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surface_data = interior_data[interior_data[:,1] == interior_data[:,1].max()]
temp_surface = temp_net(surface_data.cpu())

x, y, z = surface_data[:, 0].cpu().detach().numpy(), surface_data[:, 1].cpu().detach().numpy(), surface_data[:, 2].cpu().detach().numpy()

scatter = ax.scatter(x, y, z, c=temp_surface.cpu().detach().view(-1).numpy(), cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Temperature')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Temperature Field')

plt.show()

# %%
surface_data

# %%
# %matplotlib inline

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Generate Y-Z grid
y_values = np.linspace(-2, 2, 100)
z_values = np.linspace(-2, 2, 100)
y_grid, z_grid = np.meshgrid(y_values, z_values)

# Prepare the data for the neural network
x_fixed = - np.ones_like(y_grid)  # X-coordinate is fixed at 1
norm_speed = np.full_like(y_grid, interior_data[0, 3].detach())  # Normalized speed
norm_power = np.full_like(y_grid, interior_data[0, 4].detach())  # Normalized power

# Reshape the data and concatenate all columns
nn_input = np.stack([x_fixed.ravel(), y_grid.ravel(), z_grid.ravel(), norm_speed.ravel(), norm_power.ravel()], axis=1)

# Convert to PyTorch tensor
nn_input_tensor = torch.tensor(nn_input, dtype=torch.float32)

# Evaluate the temperature field using the neural network
with torch.no_grad():
    temp_field = temp_net(nn_input_tensor).cpu().numpy()

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(nn_input[:, 0], nn_input[:, 1], nn_input[:, 2], c=temp_field.ravel(), cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Temperature')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Temperature Field in Y-Z Plane at X=-1')

plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Generate X-Z grid
x_values = np.linspace(-6, 2, 100)
z_values = np.linspace(-2, 2, 100)
x_grid, z_grid = np.meshgrid(x_values, z_values)

# Prepare the data for the neural network
y_fixed = np.ones_like(x_grid)  # Y-coordinate is fixed at 1
norm_speed = np.full_like(x_grid, interior_data[0, 3].detach())  # Normalized speed
norm_power = np.full_like(x_grid, interior_data[0, 4].detach())  # Normalized power

# Reshape the data and concatenate all columns
nn_input = np.stack([x_grid.ravel(), y_fixed.ravel(), z_grid.ravel(), norm_speed.ravel(), norm_power.ravel()], axis=1)

# Convert to PyTorch tensor
nn_input_tensor = torch.tensor(nn_input, dtype=torch.float32)

# Evaluate the temperature field using the neural network
with torch.no_grad():
    temp_field = temp_net(nn_input_tensor).cpu().numpy()

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(nn_input[:, 0], nn_input[:, 1], nn_input[:, 2], c=temp_field.ravel(), cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Temperature')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Temperature Field in X-Z Plane at Y=1')

plt.show()

# %%
torch.save(temp_net, 'temp_net_trained_ADV_neg')

# %%
nn_input

# %%
# Create a 3D scatter plot for temperature
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot interior_data points
x_interior, y_interior, z_interior = interior_data[:, 0].cpu().detach().numpy(), interior_data[:, 1].cpu().detach().numpy(), interior_data[:, 2].cpu().detach().numpy()
scatter_interior = ax.scatter(x_interior, y_interior, z_interior, c=temp.cpu().detach().numpy(), cmap='coolwarm')

# Plot boundary_data points in red
x_boundary, y_boundary, z_boundary = boundary_data[:, 0].cpu().detach().numpy(), boundary_data[:, 1].cpu().detach().numpy(), boundary_data[:, 2].cpu().detach().numpy()
scatter_boundary = ax.scatter(x_boundary, y_boundary, z_boundary, c='red', label='Boundary Data')

# Add a colorbar to indicate temperature values for the interior points
cbar = fig.colorbar(scatter_interior, ax=ax, orientation='vertical')
cbar.set_label('Temperature')

# Label the axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Add title
plt.title('Temperature Field')

# Add legend
ax.legend()

# Show the plot
plt.show()

# %%
# Find the maximum Y value
y_max = np.max(y)

# Create a mask for the points that are on the plane y = y_max
mask_y_max = (y == y_max)

# Filter the x, y, z coordinates and the adv values
x_filtered = x[mask_y_max]
y_filtered = y[mask_y_max]
z_filtered = z[mask_y_max]

adv = rho * Cp * temp_gradients_interior[:, 0].cpu() * speed.flatten().cpu()
adv_filtered = adv.cpu().detach().numpy()[mask_y_max]

# Create a 3D scatter plot for temperature
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Only plot the points that lie on the plane y = y_max
scatter = ax.scatter(x_filtered, y_filtered, z_filtered, c=adv_filtered, cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Q')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Advection term on the plane y = y_max')

plt.show()

print("Maximum value of advection term:", np.max(adv_filtered))

# %%
# Find the maximum Y value
y_max = np.max(y)

# Create a mask for the points that are on the plane y = y_max
mask_y_max = (y == y_max)

# Filter the x, y, z coordinates and the diff values
x_filtered = x[mask_y_max]
y_filtered = y[mask_y_max]
z_filtered = z[mask_y_max]
diff = kappa * temp_laplacian_interior
diff_filtered = diff.cpu().detach().numpy()[mask_y_max]

# Create a 3D scatter plot for temperature
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Only plot the points that lie on the plane y = y_max
scatter = ax.scatter(x_filtered, y_filtered, z_filtered, c=diff_filtered, cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Q')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Diffusion term on the plane y = y_max')

plt.show()

print("Maximum value of diffusion term:", np.max(diff_filtered))

# %%
# Compute the heat equation residual
heat_equation_residual = (
    rho * Cp * temp_gradients_interior[:, 0] * speed.flatten()
    - kappa * temp_laplacian_interior - Q_values_interior
)

# %%
from torch.optim import LBFGS, Adam

# Initialize Neural Networks
temp_net = TempFieldNN().to(device).train()
fluid_net = FluidFlowNN().to(device).train()

# Initialize L-BFGS Optimizer
params = list(temp_net.parameters()) + list(fluid_net.parameters())
optimizer = Adam(params, lr=1e-3) #LBFGS(params, line_search_fn="strong_wolfe")

# Loss function
criterion = nn.MSELoss()

# List of all sample names
all_samples = conditions_df['Sample Name'].tolist()

# Leave-One-Out Cross-Validation
for exclude_sample in all_samples:
    print(f"Excluding sample: {exclude_sample} for validation.")

    # Create Data Loaders
    train_loader, val_loader = create_data_loader(exclude_sample, global_x_max, global_x_min, global_y_max, 
                                                  global_y_min, global_z_max, global_z_min,
                                                  sample_coordinates, sample_boundary_coordinates,
                                                  sample_interior_coordinates, conditions_df, data_frames)
    
    # Inner training loop
    for epoch in range(num_epochs):  
        loss_epoch = 0.0
        for i, sample_data in enumerate(train_loader, 0):
            boundary_data = sample_data['boundary'][0].to(device)
            interior_data = sample_data['interior'][0].to(device)
            sample_name = sample_data['sample'][0]
            
            # Unnormalize conditions
            speed = unnormalize_tensor(interior_data[:, 3], global_speed_min, global_speed_max)
            power = unnormalize_tensor(interior_data[:, 4], global_power_min, global_power_max)
            
            # Unnormalize coordinates
            interior_coords_unnorm = unnormalize_coordinates(interior_data[:, :3], global_x_min, 
                                                             global_x_max, global_y_min, 
                                                             global_y_max, global_z_min, global_z_max)

            print(f"Processing sample: {sample_name}")

            # Set the coordinates to require gradient computation
            boundary_data.requires_grad = True
            interior_data.requires_grad = True
            
            # Compute heat source for the interior coordinates
            Q_values_interior = heat_source(interior_coords_unnorm / 1000, power, spot_radius, eta)     

            def closure():
                optimizer.zero_grad()
                # Initialize total loss
                total_loss = 0.0

                # Temperature Boundary Computations
                temp_at_boundary = temp_net(boundary_data)

                # Compute temperature gradients at the boundary
                temp_gradients_boundary = torch.autograd.grad(
                    temp_at_boundary.sum(), boundary_data,
                    create_graph=True, retain_graph=True
                )[0][:, :3]

                # Compute the adiabatic residual at the boundary
                adiabatic_residual_boundary = torch.mean(temp_gradients_boundary ** 2)
                total_loss += adiabatic_residual_boundary

                # Compute temperature residual at the boundary
                temp_residual_boundary = temp_at_boundary - T_amb
                temp_residual_boundary_mean = torch.mean(temp_residual_boundary ** 2)
                total_loss += temp_residual_boundary_mean

                # Fluid Boundary Computations
                fluid_at_boundary = fluid_net(boundary_data)

                # Compute fluid residual at the boundary
                fluid_residual_boundary = torch.mean(fluid_at_boundary ** 2)
                total_loss += fluid_residual_boundary

                # Temperature Interior Computations
                temp_at_interior = temp_net(interior_data)

                # Compute temperature gradients at the interior
                temp_gradients_interior = torch.autograd.grad(
                    temp_at_interior.sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0]

                # Compute second partial derivatives (Laplacian components) for temperature at the interior
                temp_gradients_interior_second = torch.autograd.grad(
                    temp_gradients_interior.sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][:, :3]

                # Compute the Laplacian of temperature at the interior
                temp_laplacian_interior = temp_gradients_interior_second.sum(dim=1)

                # Fluid Interior Computations
                fluid_at_interior = fluid_net(interior_data)

                # Find Minimum Y-Coordinate for Surface (Still Negative)
                interior_coordinates = interior_data[:, :3]
                min_y_surface = interior_coordinates[:, 1][interior_coordinates[:, 1] < 0].max()

                # Create Mask for Surface (Smallest Y but Still Negative)
                mask_surface = (interior_coordinates[:, 1] == min_y_surface)

                # Create Mask for Temperature Greater Than Melting Point
                mask_temp_above_melt = (temp_at_interior > T_melt).view(-1)

                # Combine Both Masks
                mask_surface_and_above_melt = mask_surface.view(-1) & mask_temp_above_melt.view(-1)

                # Compute X-Component Fluid Gradients at Surface and Above Melting Point
                fluid_gradients_x = torch.autograd.grad(
                    fluid_at_interior[:, 0].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][mask_surface_and_above_melt, :3]

                # Compute Z-Component Fluid Gradients at Surface and Above Melting Point
                fluid_gradients_z = torch.autograd.grad(
                    fluid_at_interior[:, 2].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][mask_surface_and_above_melt, :3]

                # Compute Temperature Gradients at Surface and Above Melting Point
                temp_gradients_surface_melt = torch.autograd.grad(
                    temp_at_interior.sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][mask_surface_and_above_melt, :3]

                # Marangoni Constraint 1
                if fluid_gradients_x.nelement() == 0 or temp_gradients_surface_melt.nelement() == 0:
                    # print("Warning: Either fluid_gradients_x or temp_gradients_surface_melt is empty for constraint_marangoni_1, setting its contribution to zero.")
                    constraint_marangoni_1_mean_squared = torch.tensor(0.0, requires_grad=True).to(fluid_gradients_x.device)  # Make sure it's on the same device
                else:
                    constraint_marangoni_1 = mu * fluid_gradients_x[:, 1] - temp_gradients_surface_melt[:, 0] * dgamma_dt
                    constraint_marangoni_1_mean_squared = torch.mean(constraint_marangoni_1 ** 2)
                # Add to total loss
                total_loss += constraint_marangoni_1_mean_squared

                # Marangoni Constraint 2
                if fluid_gradients_z.nelement() == 0 or temp_gradients_surface_melt.nelement() == 0:
                    # print("Warning: Either fluid_gradients_z or temp_gradients_surface_melt is empty for constraint_marangoni_2, setting its contribution to zero.")
                    constraint_marangoni_2_mean_squared = torch.tensor(0.0, requires_grad=True).to(fluid_gradients_z.device)  # Make sure it's on the same device
                else:
                    constraint_marangoni_2 = mu * fluid_gradients_z[:, 1] - temp_gradients_surface_melt[:, 2] * dgamma_dt
                    constraint_marangoni_2_mean_squared = torch.mean(constraint_marangoni_2 ** 2)
                # Add to total loss
                total_loss += constraint_marangoni_2_mean_squared

                # No Vertical Fluid Velocity at the Surface
                total_loss += torch.mean(fluid_at_interior[mask_surface][:, 1] ** 2)

                # No Fluid Flow Outside Liquid Phase
                mask_temp_below_melt = ~mask_temp_above_melt.view(-1)
                total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 0] ** 2)
                total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 1] ** 2)
                total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 2] ** 2)

                # Compute Fluid Divergence
                fluid_gradients_vx = torch.autograd.grad(
                    fluid_at_interior[:, 0].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][:, 0]

                fluid_gradients_vy = torch.autograd.grad(
                    fluid_at_interior[:, 1].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][:, 1]

                fluid_gradients_vz = torch.autograd.grad(
                    fluid_at_interior[:, 2].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][:, 2]

                # Compute Divergence: div(V) = dVx/dx + dVy/dy + dVz/dz
                fluid_divergence = fluid_gradients_vx + fluid_gradients_vy + fluid_gradients_vz

                # Enforce Zero Divergence for Fluid
                total_loss += torch.mean(fluid_divergence ** 2)

                # Compute inner product between temperature gradients and fluid velocity in the interior
                inner_product_temp_gradients_fluid_velocity = (temp_gradients_interior[:, :3] * fluid_at_interior).sum(dim=1)

                # Compute the heat equation residual
                heat_equation_residual = (
                    rho * Cp * inner_product_temp_gradients_fluid_velocity
                    - rho * Cp * temp_gradients_interior[:, 0] * speed.flatten()
                    - kappa * temp_laplacian_interior - Q_values_interior
                )

                # Compute the mean square of the heat equation residual
                heat_equation_residual_mean = torch.mean(heat_equation_residual ** 2)

                # Add heat equation residual to the total loss
                total_loss += heat_equation_residual_mean

                # Add Penalty for Negative Temperatures
                negative_temp_penalty = torch.nn.ReLU()(-temp_at_interior)
                negative_temp_penalty_mean = torch.mean(negative_temp_penalty ** 2)

                # Add negative temperature penalty to the total loss
                total_loss += negative_temp_penalty_mean
                
                total_loss.backward()
                
                # Print each component of the total loss for debugging and analysis
#                 print("Component-wise Loss Contributions:")
#                 print(f"Adiabatic Residual at Boundary: {adiabatic_residual_boundary.item():.6f}")
#                 print(f"Temperature Residual at Boundary: {temp_residual_boundary_mean.item():.6f}")
#                 print(f"Fluid Residual at Boundary: {fluid_residual_boundary.item():.6f}")
#                 print(f"Marangoni Constraint 1: {constraint_marangoni_1_mean_squared.item():.6f}")
#                 print(f"Marangoni Constraint 2: {constraint_marangoni_2_mean_squared.item():.6f}")
#                 print(f"Vertical Fluid Velocity at Surface: {torch.mean(fluid_at_interior[mask_surface][:, 1] ** 2).item():.6f}")
#                 print(f"Fluid Flow Outside Liquid Phase: {torch.mean(fluid_at_interior[mask_temp_below_melt][:, 0] ** 2).item():.6f}")
#                 print(f"Fluid Divergence: {torch.mean(fluid_divergence ** 2).item():.6f}")
#                 print(f"Heat Equation Residual: {heat_equation_residual_mean.item():.6f}")
#                 print(f"Negative Temperature Penalty: {negative_temp_penalty_mean.item():.6f}")
#                 print(f"Total Loss: {total_loss.item():.6f}")
                
                
                return total_loss

            # Backward pass and optimization using L-BFGS
            loss = optimizer.step(closure)
            loss_epoch += loss.item()
            
            #print(f"Epoch: {epoch}, Sample: {sample_name}, Loss: {loss.item()}")
            print("-------"*8)
            
        print(f"DONE with Epoch: {epoch}, Sample: {sample_name}, Loss: {loss.item()}, Loss EPOCH: {loss_epoch}")    
    print(f"Finished LOOCV for excluded sample: {exclude_sample}")

print("Finished all LOOCV cycles.")

# %%
# Initialize L-BFGS Optimizer
params = list(temp_net.parameters()) + list(fluid_net.parameters())
optimizer = LBFGS(params, line_search_fn="strong_wolfe", max_iter=2500)

# Loss function
criterion = nn.MSELoss()

# List of all sample names
all_samples = conditions_df['Sample Name'].tolist()

# Leave-One-Out Cross-Validation
for exclude_sample in all_samples:
    print(f"Excluding sample: {exclude_sample} for validation.")

    # Create Data Loaders
    train_loader, val_loader = create_data_loader(exclude_sample, global_x_max, global_x_min, global_y_max, 
                                                  global_y_min, global_z_max, global_z_min,
                                                  sample_coordinates, sample_boundary_coordinates,
                                                  sample_interior_coordinates, conditions_df, data_frames)
    
    # Inner training loop
    for epoch in range(num_epochs):  
        loss_epoch = 0.0
        for i, sample_data in enumerate(train_loader, 0):
            boundary_data = sample_data['boundary'][0].to(device)
            interior_data = sample_data['interior'][0].to(device)
            sample_name = sample_data['sample'][0]
            
            # Unnormalize conditions
            speed = unnormalize_tensor(interior_data[:, 3], global_speed_min, global_speed_max)
            power = unnormalize_tensor(interior_data[:, 4], global_power_min, global_power_max)
            
            # Unnormalize coordinates
            interior_coords_unnorm = unnormalize_coordinates(interior_data[:, :3], global_x_min, 
                                                             global_x_max, global_y_min, 
                                                             global_y_max, global_z_min, global_z_max)

            print(f"Processing sample: {sample_name}")

            # Set the coordinates to require gradient computation
            boundary_data.requires_grad = True
            interior_data.requires_grad = True
            
            # Compute heat source for the interior coordinates
            Q_values_interior = heat_source(interior_coords_unnorm / 1000, power, spot_radius, eta)     

            def closure():
                optimizer.zero_grad()
                # Initialize total loss
                total_loss = 0.0

                # Temperature Boundary Computations
                temp_at_boundary = temp_net(boundary_data)

                # Compute temperature gradients at the boundary
                temp_gradients_boundary = torch.autograd.grad(
                    temp_at_boundary.sum(), boundary_data,
                    create_graph=True, retain_graph=True
                )[0][:, :3]

                # Compute the adiabatic residual at the boundary
                adiabatic_residual_boundary = torch.mean(temp_gradients_boundary ** 2)
                total_loss += adiabatic_residual_boundary

                # Compute temperature residual at the boundary
                temp_residual_boundary = temp_at_boundary - T_amb
                temp_residual_boundary_mean = torch.mean(temp_residual_boundary ** 2)
                total_loss += temp_residual_boundary_mean

                # Fluid Boundary Computations
                fluid_at_boundary = fluid_net(boundary_data)

                # Compute fluid residual at the boundary
                fluid_residual_boundary = torch.mean(fluid_at_boundary ** 2)
                total_loss += fluid_residual_boundary

                # Temperature Interior Computations
                temp_at_interior = temp_net(interior_data)

                # Compute temperature gradients at the interior
                temp_gradients_interior = torch.autograd.grad(
                    temp_at_interior.sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0]

                # Compute second partial derivatives (Laplacian components) for temperature at the interior
                temp_gradients_interior_second = torch.autograd.grad(
                    temp_gradients_interior.sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][:, :3]

                # Compute the Laplacian of temperature at the interior
                temp_laplacian_interior = temp_gradients_interior_second.sum(dim=1)

                # Fluid Interior Computations
                fluid_at_interior = fluid_net(interior_data)

                # Find Minimum Y-Coordinate for Surface (Still Negative)
                interior_coordinates = interior_data[:, :3]
                min_y_surface = interior_coordinates[:, 1][interior_coordinates[:, 1] < 0].max()

                # Create Mask for Surface (Smallest Y but Still Negative)
                mask_surface = (interior_coordinates[:, 1] == min_y_surface)

                # Create Mask for Temperature Greater Than Melting Point
                mask_temp_above_melt = (temp_at_interior > T_melt).view(-1)

                # Combine Both Masks
                mask_surface_and_above_melt = mask_surface.view(-1) & mask_temp_above_melt.view(-1)

                # Compute X-Component Fluid Gradients at Surface and Above Melting Point
                fluid_gradients_x = torch.autograd.grad(
                    fluid_at_interior[:, 0].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][mask_surface_and_above_melt, :3]

                # Compute Z-Component Fluid Gradients at Surface and Above Melting Point
                fluid_gradients_z = torch.autograd.grad(
                    fluid_at_interior[:, 2].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][mask_surface_and_above_melt, :3]

                # Compute Temperature Gradients at Surface and Above Melting Point
                temp_gradients_surface_melt = torch.autograd.grad(
                    temp_at_interior.sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][mask_surface_and_above_melt, :3]

                # Marangoni Constraint 1
                if fluid_gradients_x.nelement() == 0 or temp_gradients_surface_melt.nelement() == 0:
                    # print("Warning: Either fluid_gradients_x or temp_gradients_surface_melt is empty for constraint_marangoni_1, setting its contribution to zero.")
                    constraint_marangoni_1_mean_squared = torch.tensor(0.0, requires_grad=True).to(fluid_gradients_x.device)  # Make sure it's on the same device
                else:
                    constraint_marangoni_1 = mu * fluid_gradients_x[:, 1] - temp_gradients_surface_melt[:, 0] * dgamma_dt
                    constraint_marangoni_1_mean_squared = torch.mean(constraint_marangoni_1 ** 2)
                # Add to total loss
                total_loss += constraint_marangoni_1_mean_squared

                # Marangoni Constraint 2
                if fluid_gradients_z.nelement() == 0 or temp_gradients_surface_melt.nelement() == 0:
                    # print("Warning: Either fluid_gradients_z or temp_gradients_surface_melt is empty for constraint_marangoni_2, setting its contribution to zero.")
                    constraint_marangoni_2_mean_squared = torch.tensor(0.0, requires_grad=True).to(fluid_gradients_z.device)  # Make sure it's on the same device
                else:
                    constraint_marangoni_2 = mu * fluid_gradients_z[:, 1] - temp_gradients_surface_melt[:, 2] * dgamma_dt
                    constraint_marangoni_2_mean_squared = torch.mean(constraint_marangoni_2 ** 2)
                # Add to total loss
                total_loss += constraint_marangoni_2_mean_squared

                # No Vertical Fluid Velocity at the Surface
                total_loss += torch.mean(fluid_at_interior[mask_surface][:, 1] ** 2)

                # No Fluid Flow Outside Liquid Phase
                mask_temp_below_melt = ~mask_temp_above_melt.view(-1)
                total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 0] ** 2)
                total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 1] ** 2)
                total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 2] ** 2)

                # Compute Fluid Divergence
                fluid_gradients_vx = torch.autograd.grad(
                    fluid_at_interior[:, 0].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][:, 0]

                fluid_gradients_vy = torch.autograd.grad(
                    fluid_at_interior[:, 1].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][:, 1]

                fluid_gradients_vz = torch.autograd.grad(
                    fluid_at_interior[:, 2].sum(), interior_data,
                    create_graph=True, retain_graph=True
                )[0][:, 2]

                # Compute Divergence: div(V) = dVx/dx + dVy/dy + dVz/dz
                fluid_divergence = fluid_gradients_vx + fluid_gradients_vy + fluid_gradients_vz

                # Enforce Zero Divergence for Fluid
                total_loss += torch.mean(fluid_divergence ** 2)

                # Compute inner product between temperature gradients and fluid velocity in the interior
                inner_product_temp_gradients_fluid_velocity = (temp_gradients_interior[:, :3] * fluid_at_interior).sum(dim=1)

                # Compute the heat equation residual
                heat_equation_residual = (
                    rho * Cp * inner_product_temp_gradients_fluid_velocity
                    + rho * Cp * temp_gradients_interior[:, 0] * speed.flatten()
                    - kappa * temp_laplacian_interior - Q_values_interior
                )

                # Compute the mean square of the heat equation residual
                heat_equation_residual_mean = torch.mean(heat_equation_residual ** 2)

                # Add heat equation residual to the total loss
                total_loss += heat_equation_residual_mean

                # Add Penalty for Negative Temperatures
                negative_temp_penalty = torch.nn.ReLU()(-temp_at_interior)
                negative_temp_penalty_mean = torch.mean(negative_temp_penalty ** 2)

                # Add negative temperature penalty to the total loss
                total_loss += negative_temp_penalty_mean
                
                total_loss.backward()
                
                # Print each component of the total loss for debugging and analysis
                print("Component-wise Loss Contributions:")
                print(f"Adiabatic Residual at Boundary: {adiabatic_residual_boundary.item():.6f}")
                print(f"Temperature Residual at Boundary: {temp_residual_boundary_mean.item():.6f}")
                print(f"Fluid Residual at Boundary: {fluid_residual_boundary.item():.6f}")
                print(f"Marangoni Constraint 1: {constraint_marangoni_1_mean_squared.item():.6f}")
                print(f"Marangoni Constraint 2: {constraint_marangoni_2_mean_squared.item():.6f}")
                print(f"Vertical Fluid Velocity at Surface: {torch.mean(fluid_at_interior[mask_surface][:, 1] ** 2).item():.6f}")
                print(f"Fluid Flow Outside Liquid Phase: {torch.mean(fluid_at_interior[mask_temp_below_melt][:, 0] ** 2).item():.6f}")
                print(f"Fluid Divergence: {torch.mean(fluid_divergence ** 2).item():.6f}")
                print(f"Heat Equation Residual: {heat_equation_residual_mean.item():.6f}")
                print(f"Negative Temperature Penalty: {negative_temp_penalty_mean.item():.6f}")
                print(f"Total Loss: {total_loss.item():.6f}")
                
                
                return total_loss

            # Backward pass and optimization using L-BFGS
            loss = optimizer.step(closure)
            loss_epoch += loss.item()
            
            print(f"Epoch: {epoch}, Sample: {sample_name}, Loss: {loss.item()}")
            print("-------"*8)
            
        print(f"DONE with Epoch: {epoch}, Sample: {sample_name}, Loss: {loss.item()}, Loss EPOCH: {loss_epoch}")    
    print(f"Finished LOOCV for excluded sample: {exclude_sample}")

print("Finished all LOOCV cycles.")

# %%
# Initialize L-BFGS Optimizer
params = list(temp_net.parameters()) + list(fluid_net.parameters())
optimizer = LBFGS(params, line_search_fn="strong_wolfe", max_iter=2500)

# Loss function
criterion = nn.MSELoss()

# List of all sample names
all_samples = conditions_df['Sample Name'].tolist()


boundary_data = sample_data['boundary'][0].to(device)
interior_data = sample_data['interior'][0].to(device)
sample_name = sample_data['sample'][0]

# Unnormalize conditions
speed = unnormalize_tensor(interior_data[:, 3], global_speed_min, global_speed_max)
power = unnormalize_tensor(interior_data[:, 4], global_power_min, global_power_max)

# Unnormalize coordinates
interior_coords_unnorm = unnormalize_coordinates(interior_data[:, :3], global_x_min, 
                                                 global_x_max, global_y_min, 
                                                 global_y_max, global_z_min, global_z_max)

print(f"Processing sample: {sample_name}")

# Set the coordinates to require gradient computation
boundary_data.requires_grad = True
interior_data.requires_grad = True

# Compute heat source for the interior coordinates
Q_values_interior = heat_source(interior_coords_unnorm / 1000, power, spot_radius, eta)     

def closure():
    optimizer.zero_grad()
    # Initialize total loss
    total_loss = 0.0

    # Temperature Boundary Computations
    temp_at_boundary = temp_net(boundary_data)

    # Compute temperature gradients at the boundary
    temp_gradients_boundary = torch.autograd.grad(
        temp_at_boundary.sum(), boundary_data,
        create_graph=True, retain_graph=True
    )[0][:, :3]

    # Compute the adiabatic residual at the boundary
    adiabatic_residual_boundary = torch.mean(temp_gradients_boundary ** 2)
    total_loss += adiabatic_residual_boundary

    # Compute temperature residual at the boundary
    temp_residual_boundary = temp_at_boundary - T_amb
    temp_residual_boundary_mean = torch.mean(temp_residual_boundary ** 2)
    total_loss += temp_residual_boundary_mean

    # Fluid Boundary Computations
    fluid_at_boundary = fluid_net(boundary_data)

    # Compute fluid residual at the boundary
    fluid_residual_boundary = torch.mean(fluid_at_boundary ** 2)
    total_loss += fluid_residual_boundary

    # Temperature Interior Computations
    temp_at_interior = temp_net(interior_data)

    # Compute temperature gradients at the interior
    temp_gradients_interior = torch.autograd.grad(
        temp_at_interior.sum(), interior_data,
        create_graph=True, retain_graph=True
    )[0]

    # Compute second partial derivatives (Laplacian components) for temperature at the interior
    temp_gradients_interior_second = torch.autograd.grad(
        temp_gradients_interior.sum(), interior_data,
        create_graph=True, retain_graph=True
    )[0][:, :3]

    # Compute the Laplacian of temperature at the interior
    temp_laplacian_interior = temp_gradients_interior_second.sum(dim=1)

    # Fluid Interior Computations
    fluid_at_interior = fluid_net(interior_data)

    # Find Minimum Y-Coordinate for Surface (Still Negative)
    interior_coordinates = interior_data[:, :3]
    min_y_surface = interior_coordinates[:, 1][interior_coordinates[:, 1] < 0].max()

    # Create Mask for Surface (Smallest Y but Still Negative)
    mask_surface = (interior_coordinates[:, 1] == min_y_surface)

    # Create Mask for Temperature Greater Than Melting Point
    mask_temp_above_melt = (temp_at_interior > T_melt).view(-1)

    # Combine Both Masks
    mask_surface_and_above_melt = mask_surface.view(-1) & mask_temp_above_melt.view(-1)

    # Compute X-Component Fluid Gradients at Surface and Above Melting Point
    fluid_gradients_x = torch.autograd.grad(
        fluid_at_interior[:, 0].sum(), interior_data,
        create_graph=True, retain_graph=True
    )[0][mask_surface_and_above_melt, :3]

    # Compute Z-Component Fluid Gradients at Surface and Above Melting Point
    fluid_gradients_z = torch.autograd.grad(
        fluid_at_interior[:, 2].sum(), interior_data,
        create_graph=True, retain_graph=True
    )[0][mask_surface_and_above_melt, :3]

    # Compute Temperature Gradients at Surface and Above Melting Point
    temp_gradients_surface_melt = torch.autograd.grad(
        temp_at_interior.sum(), interior_data,
        create_graph=True, retain_graph=True
    )[0][mask_surface_and_above_melt, :3]

    # Marangoni Constraint 1
    if fluid_gradients_x.nelement() == 0 or temp_gradients_surface_melt.nelement() == 0:
        # print("Warning: Either fluid_gradients_x or temp_gradients_surface_melt is empty for constraint_marangoni_1, setting its contribution to zero.")
        constraint_marangoni_1_mean_squared = torch.tensor(0.0, requires_grad=True).to(fluid_gradients_x.device)  # Make sure it's on the same device
    else:
        constraint_marangoni_1 = mu * fluid_gradients_x[:, 1] - temp_gradients_surface_melt[:, 0] * dgamma_dt
        constraint_marangoni_1_mean_squared = torch.mean(constraint_marangoni_1 ** 2)
    # Add to total loss
    total_loss += constraint_marangoni_1_mean_squared

    # Marangoni Constraint 2
    if fluid_gradients_z.nelement() == 0 or temp_gradients_surface_melt.nelement() == 0:
        # print("Warning: Either fluid_gradients_z or temp_gradients_surface_melt is empty for constraint_marangoni_2, setting its contribution to zero.")
        constraint_marangoni_2_mean_squared = torch.tensor(0.0, requires_grad=True).to(fluid_gradients_z.device)  # Make sure it's on the same device
    else:
        constraint_marangoni_2 = mu * fluid_gradients_z[:, 1] - temp_gradients_surface_melt[:, 2] * dgamma_dt
        constraint_marangoni_2_mean_squared = torch.mean(constraint_marangoni_2 ** 2)
    # Add to total loss
    total_loss += constraint_marangoni_2_mean_squared

    # No Vertical Fluid Velocity at the Surface
    total_loss += torch.mean(fluid_at_interior[mask_surface][:, 1] ** 2)

    # No Fluid Flow Outside Liquid Phase
    mask_temp_below_melt = ~mask_temp_above_melt.view(-1)
    total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 0] ** 2)
    total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 1] ** 2)
    total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 2] ** 2)

    # Compute Fluid Divergence
    fluid_gradients_vx = torch.autograd.grad(
        fluid_at_interior[:, 0].sum(), interior_data,
        create_graph=True, retain_graph=True
    )[0][:, 0]

    fluid_gradients_vy = torch.autograd.grad(
        fluid_at_interior[:, 1].sum(), interior_data,
        create_graph=True, retain_graph=True
    )[0][:, 1]

    fluid_gradients_vz = torch.autograd.grad(
        fluid_at_interior[:, 2].sum(), interior_data,
        create_graph=True, retain_graph=True
    )[0][:, 2]

    # Compute Divergence: div(V) = dVx/dx + dVy/dy + dVz/dz
    fluid_divergence = fluid_gradients_vx + fluid_gradients_vy + fluid_gradients_vz

    # Enforce Zero Divergence for Fluid
    total_loss += torch.mean(fluid_divergence ** 2)

    # Compute inner product between temperature gradients and fluid velocity in the interior
    inner_product_temp_gradients_fluid_velocity = (temp_gradients_interior[:, :3] * fluid_at_interior).sum(dim=1)

    # Compute the heat equation residual
    heat_equation_residual = (
        rho * Cp * inner_product_temp_gradients_fluid_velocity
        + rho * Cp * temp_gradients_interior[:, 0] * speed.flatten()
        - kappa * temp_laplacian_interior - Q_values_interior
    )

    # Compute the mean square of the heat equation residual
    heat_equation_residual_mean = torch.mean(heat_equation_residual ** 2)

    # Add heat equation residual to the total loss
    total_loss += heat_equation_residual_mean

    # Add Penalty for Negative Temperatures
    negative_temp_penalty = torch.nn.ReLU()(-temp_at_interior)
    negative_temp_penalty_mean = torch.mean(negative_temp_penalty ** 2)

    # Add negative temperature penalty to the total loss
    total_loss += negative_temp_penalty_mean

    total_loss.backward()

    # Print each component of the total loss for debugging and analysis
    print("Component-wise Loss Contributions:")
    print(f"Adiabatic Residual at Boundary: {adiabatic_residual_boundary.item():.6f}")
    print(f"Temperature Residual at Boundary: {temp_residual_boundary_mean.item():.6f}")
    print(f"Fluid Residual at Boundary: {fluid_residual_boundary.item():.6f}")
    print(f"Marangoni Constraint 1: {constraint_marangoni_1_mean_squared.item():.6f}")
    print(f"Marangoni Constraint 2: {constraint_marangoni_2_mean_squared.item():.6f}")
    print(f"Vertical Fluid Velocity at Surface: {torch.mean(fluid_at_interior[mask_surface][:, 1] ** 2).item():.6f}")
    print(f"Fluid Flow Outside Liquid Phase: {torch.mean(fluid_at_interior[mask_temp_below_melt][:, 0] ** 2).item():.6f}")
    print(f"Fluid Divergence: {torch.mean(fluid_divergence ** 2).item():.6f}")
    print(f"Heat Equation Residual: {heat_equation_residual_mean.item():.6f}")
    print(f"Negative Temperature Penalty: {negative_temp_penalty_mean.item():.6f}")
    print(f"Total Loss: {total_loss.item():.6f}")


    return total_loss

# Backward pass and optimization using L-BFGS
loss = optimizer.step(closure)
loss_epoch += loss.item()

print(f"Epoch: {epoch}, Sample: {sample_name}, Loss: {loss.item()}")
print("-------"*8)

# %%
# Backward pass and optimization using L-BFGS
loss = optimizer.step(closure)
loss_epoch += loss.item()

print(f"Epoch: {epoch}, Sample: {sample_name}, Loss: {loss.item()}")
print("-------"*8)

# %%
# Temperature Boundary Computations
temp = temp_net(interior_data)
temp.max()

# %%
fluid_at_interior = fluid_net(interior_data)
fluid_at_interior

# %%
x, y, z = interior_data[:, 0].cpu().detach().numpy(), interior_data[:, 1].cpu().detach().numpy(), interior_data[:, 2].cpu().detach().numpy()
u, v, w = fluid_at_interior[:, 0].cpu().detach().numpy(), fluid_at_interior[:, 1].cpu().detach().numpy(), fluid_at_interior[:, 2].cpu().detach().numpy()

# Create a 3D quiver plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.quiver(x, y, z, u, v, w, length=0.1, normalize=True)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Fluid Velocity Field')

plt.show()

# %%
# Create a 3D scatter plot for temperature
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x, y, z = interior_data[:, 0].cpu().detach().numpy(), interior_data[:, 1].cpu().detach().numpy(), interior_data[:, 2].cpu().detach().numpy()

scatter = ax.scatter(x, y, z, c=temp.cpu().detach().numpy(), cmap='coolwarm')

# Add a colorbar to indicate temperature values
cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Temperature')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Temperature Field')

plt.show()

# %%
optimizer.zero_grad()
# Initialize total loss
total_loss = 0.0

# Temperature Boundary Computations
temp_at_boundary = temp_net(boundary_data)

# Compute temperature gradients at the boundary
temp_gradients_boundary = torch.autograd.grad(
    temp_at_boundary.sum(), boundary_data,
    create_graph=True, retain_graph=True
)[0][:, :3]

# Compute the adiabatic residual at the boundary
adiabatic_residual_boundary = torch.mean(temp_gradients_boundary ** 2)
total_loss += adiabatic_residual_boundary

# Compute temperature residual at the boundary
temp_residual_boundary = temp_at_boundary - T_amb
temp_residual_boundary_mean = torch.mean(temp_residual_boundary ** 2)
total_loss += temp_residual_boundary_mean

# Fluid Boundary Computations
fluid_at_boundary = fluid_net(boundary_data)

# Compute fluid residual at the boundary
fluid_residual_boundary = torch.mean(fluid_at_boundary ** 2)
total_loss += fluid_residual_boundary

# Temperature Interior Computations
temp_at_interior = temp_net(interior_data)

# Compute temperature gradients at the interior
temp_gradients_interior = torch.autograd.grad(
    temp_at_interior.sum(), interior_data,
    create_graph=True, retain_graph=True
)[0]

# Compute second partial derivatives (Laplacian components) for temperature at the interior
temp_gradients_interior_second = torch.autograd.grad(
    temp_gradients_interior.sum(), interior_data,
    create_graph=True, retain_graph=True
)[0][:, :3]

# Compute the Laplacian of temperature at the interior
temp_laplacian_interior = temp_gradients_interior_second.sum(dim=1)

# Fluid Interior Computations
fluid_at_interior = fluid_net(interior_data)

# Find Minimum Y-Coordinate for Surface (Still Negative)
interior_coordinates = interior_data[:, :3]
min_y_surface = interior_coordinates[:, 1][interior_coordinates[:, 1] < 0].max()

# Create Mask for Surface (Smallest Y but Still Negative)
mask_surface = (interior_coordinates[:, 1] == min_y_surface)

# Create Mask for Temperature Greater Than Melting Point
mask_temp_above_melt = (temp_at_interior > T_melt).view(-1)

# Combine Both Masks
mask_surface_and_above_melt = mask_surface.view(-1) & mask_temp_above_melt.view(-1)

# Compute X-Component Fluid Gradients at Surface and Above Melting Point
fluid_gradients_x = torch.autograd.grad(
    fluid_at_interior[:, 0].sum(), interior_data,
    create_graph=True, retain_graph=True
)[0][mask_surface_and_above_melt, :3]

# Compute Z-Component Fluid Gradients at Surface and Above Melting Point
fluid_gradients_z = torch.autograd.grad(
    fluid_at_interior[:, 2].sum(), interior_data,
    create_graph=True, retain_graph=True
)[0][mask_surface_and_above_melt, :3]

# Compute Temperature Gradients at Surface and Above Melting Point
temp_gradients_surface_melt = torch.autograd.grad(
    temp_at_interior.sum(), interior_data,
    create_graph=True, retain_graph=True
)[0][mask_surface_and_above_melt, :3]

# Marangoni Constraint 1
constraint_marangoni_1 = mu * fluid_gradients_x[:, 1] - temp_gradients_surface_melt[:, 0] * dgamma_dt
total_loss += torch.mean(constraint_marangoni_1 ** 2)

# Marangoni Constraint 2
constraint_marangoni_2 = mu * fluid_gradients_z[:, 1] - temp_gradients_surface_melt[:, 2] * dgamma_dt
total_loss += torch.mean(constraint_marangoni_2 ** 2)

# No Vertical Fluid Velocity at the Surface
total_loss += torch.mean(fluid_at_interior[mask_surface][:, 1] ** 2)

# No Fluid Flow Outside Liquid Phase
mask_temp_below_melt = ~mask_temp_above_melt.view(-1)
total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 0] ** 2)
total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 1] ** 2)
total_loss += torch.mean(fluid_at_interior[mask_temp_below_melt][:, 2] ** 2)

# Compute Fluid Divergence
fluid_gradients_vx = torch.autograd.grad(
    fluid_at_interior[:, 0].sum(), interior_data,
    create_graph=True, retain_graph=True
)[0][:, 0]

fluid_gradients_vy = torch.autograd.grad(
    fluid_at_interior[:, 1].sum(), interior_data,
    create_graph=True, retain_graph=True
)[0][:, 1]

fluid_gradients_vz = torch.autograd.grad(
    fluid_at_interior[:, 2].sum(), interior_data,
    create_graph=True, retain_graph=True
)[0][:, 2]

# Compute Divergence: div(V) = dVx/dx + dVy/dy + dVz/dz
fluid_divergence = fluid_gradients_vx + fluid_gradients_vy + fluid_gradients_vz

# Enforce Zero Divergence for Fluid
total_loss += torch.mean(fluid_divergence ** 2)

# Compute inner product between temperature gradients and fluid velocity in the interior
inner_product_temp_gradients_fluid_velocity = (temp_gradients_interior[:, :3] * fluid_at_interior).sum(dim=1)

# Compute the heat equation residual
heat_equation_residual = (
    rho * Cp * inner_product_temp_gradients_fluid_velocity
    + rho * Cp * temp_gradients_interior[:, 0] * speed.flatten()
    - kappa * temp_laplacian_interior - Q_values_interior
)

# Compute the mean square of the heat equation residual
heat_equation_residual_mean = torch.mean(heat_equation_residual ** 2)

# Add heat equation residual to the total loss
total_loss += heat_equation_residual_mean

# Add Penalty for Negative Temperatures
negative_temp_penalty = torch.nn.ReLU()(-temp_at_interior)
negative_temp_penalty_mean = torch.mean(negative_temp_penalty ** 2)

# Add negative temperature penalty to the total loss
total_loss += negative_temp_penalty_mean

# Print each component of the total loss for debugging and analysis
print("Component-wise Loss Contributions:")
print(f"Adiabatic Residual at Boundary: {adiabatic_residual_boundary.item():.6f}")
print(f"Temperature Residual at Boundary: {temp_residual_boundary_mean.item():.6f}")
print(f"Fluid Residual at Boundary: {fluid_residual_boundary.item():.6f}")
print(f"Marangoni Constraint 1: {torch.mean(constraint_marangoni_1 ** 2).item():.6f}")
print(f"Marangoni Constraint 2: {torch.mean(constraint_marangoni_2 ** 2).item():.6f}")
print(f"Vertical Fluid Velocity at Surface: {torch.mean(fluid_at_interior[mask_surface][:, 1] ** 2).item():.6f}")
print(f"Fluid Flow Outside Liquid Phase: {torch.mean(fluid_at_interior[mask_temp_below_melt][:, 0] ** 2).item():.6f}")
print(f"Fluid Divergence: {torch.mean(fluid_divergence ** 2).item():.6f}")
print(f"Heat Equation Residual: {heat_equation_residual_mean.item():.6f}")
print(f"Negative Temperature Penalty: {negative_temp_penalty_mean.item():.6f}")
print(f"Total Loss: {total_loss.item():.6f}")

# %%
temp_at_interior

# %%
constraint_marangoni_1 = mu * fluid_gradients_x[:, 1] - temp_gradients_surface_melt[:, 0] * dgamma_dt

constraint_marangoni_2 = mu * fluid_gradients_z[:, 1] - temp_gradients_surface_melt[:, 2] * dgamma_dt
constraint_marangoni_1, constraint_marangoni_2

# %%
constraint_marangoni_1.nelement() == 0

# %%
# Create the 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(interior_data[:, 0].cpu().detach().numpy(), interior_data[:, 1].cpu().detach().numpy(), interior_data[:, 2].cpu().detach().numpy(), c=Q_values_interior.cpu().detach().numpy(), cmap='viridis')

# Add color bar
cbar = plt.colorbar(sc)

# Label axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
cbar.set_label('Q_values_interior', rotation=270, labelpad=15)

# Show the plot
plt.show()

# %%
boundary_data
